# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from dateutil.parser import parse
import numpy as np

import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
events = pd.read_csv('data/events_up_to_01062018.csv')
events.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
events.count()
# Out:
# timestamp                   2341681
# event                       2341681
# person                      2341681
# url                          191131
# sku                         1320530
# model                       1321513
# condition                   1320530
# storage                     1320530
# color                       1320530
# skus                         505949
# search_term                  113763
# staticpage                    11201
# campaign_source              191286
# search_engine                106406
# channel                      204069
# new_vs_returning             204069
# city                         204069
# region                       204069
# country                      204069
# device_type                  204069
# screen_resolution            204066
# operating_system_version     204069
# browser_version              204069
# dtype: int64

# %%
label_training = pd.read_csv('data/labels_training_set.csv')
label_training.head()
# Out:
#      person  label
# 0  0566e9c1      0
# 1  6ec7ee77      0
# 2  abe7a2fb      0
# 3  34728364      0
# 4  87ed62de      0

# %%
label_training.describe()
# Out:
#               label
# count  19414.000000
# mean       0.050479
# std        0.218937
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
training_set = label_training.merge(events, how= 'inner', on = 'person')
training_set.count()
# Out:
# person                      1171886
# label                       1171886
# timestamp                   1171886
# event                       1171886
# url                           94875
# sku                          665336
# model                        665767
# condition                    665336
# storage                      665336
# color                        665336
# skus                         249587
# search_term                   55774
# staticpage                     5660
# campaign_source               94940
# search_engine                 52829
# channel                      102299
# new_vs_returning             102299
# city                         102299
# region                       102299
# country                      102299
# device_type                  102299
# screen_resolution            102297
# operating_system_version     102299
# browser_version              102299
# dtype: int64

# %%
prediction_set = events.merge(label_training, how= 'left', on = 'person')
prediction_set = prediction_set[prediction_set.label.isnull()]
prediction_set.head()
# Out:
#              timestamp              event    person  url      sku  \
# 0  2018-05-18 00:11:59     viewed product  4886f805  NaN   9288.0
# 2  2018-05-18 00:11:16     viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14     viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09     viewed product  cccea85e  NaN   7517.0
# 5  2018-05-18 00:44:27  searched products  4c8a8b93  NaN      NaN
#
#                      model  condition storage     color  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB   Dourado
# 2                iPhone 6S  Muito Bom    64GB  Prateado
# 3                 iPhone 7        Bom   128GB  Vermelho
# 4              LG G4 H818P  Excelente    32GB    Branco
# 5                      NaN        NaN     NaN       NaN
#
#                                                 skus  ...  channel  \
# 0                                                NaN  ...      NaN
# 2                                                NaN  ...      NaN
# 3                                                NaN  ...      NaN
# 4                                                NaN  ...      NaN
# 5  10240,9987,10322,10085,9944,9931,13404,10154,1...  ...      NaN
#
#   new_vs_returning city region country device_type screen_resolution  \
# 0              NaN  NaN    NaN     NaN         NaN               NaN
# 2              NaN  NaN    NaN     NaN         NaN               NaN
# 3              NaN  NaN    NaN     NaN         NaN               NaN
# 4              NaN  NaN    NaN     NaN         NaN               NaN
# 5              NaN  NaN    NaN     NaN         NaN               NaN
#
#   operating_system_version browser_version label
# 0                      NaN             NaN   NaN
# 2                      NaN             NaN   NaN
# 3                      NaN             NaN   NaN
# 4                      NaN             NaN   NaN
# 5                      NaN             NaN   NaN
#
# [5 rows x 24 columns]

# %%
prediction_set.count()
# Out:
# timestamp                   1169795
# event                       1169795
# person                      1169795
# url                           96256
# sku                          655194
# model                        655746
# condition                    655194
# storage                      655194
# color                        655194
# skus                         256362
# search_term                   57989
# staticpage                     5541
# campaign_source               96346
# search_engine                 53577
# channel                      101770
# new_vs_returning             101770
# city                         101770
# region                       101770
# country                      101770
# device_type                  101770
# screen_resolution            101769
# operating_system_version     101770
# browser_version              101770
# label                             0
# dtype: int64

# %%
prediction_set.to_csv('data/set_prediccion.csv', encoding='utf-8', index=False)

# %%
del prediction_set

# %%
del events
del label_training

# %% [markdown]
# # Analisis TP1

# %%
training_set.columns
# Out:
# Index(['person', 'label', 'timestamp', 'event', 'url', 'sku', 'model',
#        'condition', 'storage', 'color', 'skus', 'search_term', 'staticpage',
#        'campaign_source', 'search_engine', 'channel', 'new_vs_returning',
#        'city', 'region', 'country', 'device_type', 'screen_resolution',
#        'operating_system_version', 'browser_version'],
#       dtype='object')

# %%
training_set.drop(['url','sku','skus','city','search_engine','campaign_source','channel'], inplace=True, axis=1)

# %%
#Cambiamos el tipo de dato de fecha de timestamp a datetime para un mejor analisis y renombramos a "fecha"
training_set[['timestamp']] = training_set[['timestamp']].apply(pd.to_datetime)
training_set.rename({
    'timestamp' : 'fecha',
}, axis=1, inplace=True)
training_set.head()
# Out:
#      person  label               fecha            event model condition  \
# 0  0566e9c1      0 2018-05-24 16:42:28       staticpage   NaN       NaN
# 1  0566e9c1      0 2018-05-24 16:42:20  ad campaign hit   NaN       NaN
# 2  0566e9c1      0 2018-05-24 11:29:04  ad campaign hit   NaN       NaN
# 3  0566e9c1      0 2018-05-24 11:29:53  ad campaign hit   NaN       NaN
# 4  0566e9c1      0 2018-05-24 00:15:29  ad campaign hit   NaN       NaN
#
#   storage color search_term       staticpage new_vs_returning region country  \
# 0     NaN   NaN         NaN  CustomerService              NaN    NaN     NaN
# 1     NaN   NaN         NaN              NaN              NaN    NaN     NaN
# 2     NaN   NaN         NaN              NaN              NaN    NaN     NaN
# 3     NaN   NaN         NaN              NaN              NaN    NaN     NaN
# 4     NaN   NaN         NaN              NaN              NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN

# %%
#Detalles de Productos que fueron comprados
productos = training_set.loc[:, ['event','fecha','person','sku', 'model', 'condition', 'storage', 'color']]
productos_comprados = productos.loc[(productos.event == 'checkout') | (productos.event == 'conversion')]
productos_comprados.drop(['event'], inplace=True, axis=1)
productos_comprados.head()
# Out:
#                   fecha    person  sku              model  condition storage  \
# 5   2018-05-23 18:44:26  0566e9c1  NaN          iPhone 4S        Bom     8GB
# 7   2018-05-23 18:39:08  0566e9c1  NaN          iPhone 4S        Bom     8GB
# 85  2018-05-29 23:39:14  abe7a2fb  NaN           iPhone 6        Bom    64GB
# 208 2018-05-18 23:44:19  87ed62de  NaN  Samsung Galaxy J7  Excelente    16GB
# 215 2018-05-18 23:41:45  87ed62de  NaN  Samsung Galaxy J7  Excelente    16GB
#
#         color
# 5      Branco
# 7      Branco
# 85   Prateado
# 208   Dourado
# 215   Dourado

# %%
#Detalles de Productos que fueron visitados
productos_visitados = productos.loc[(productos.event == 'viewed product')]
productos_visitados.drop(['event'], inplace=True, axis=1)
productos_visitados.head()
# Out:
#                  fecha    person  sku      model           condition storage  \
# 8  2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G           Muito Bom    16GB
# 9  2018-05-23 18:38:05  0566e9c1  NaN  iPhone 4S                 Bom     8GB
# 10 2018-05-23 18:38:32  0566e9c1  NaN  iPhone 4S                 Bom     8GB
# 12 2018-05-22 17:55:05  0566e9c1  NaN  iPhone 5s                 Bom    16GB
# 13 2018-05-22 17:54:54  0566e9c1  NaN  iPhone 5s  Bom - Sem Touch ID    16GB
#
#        color
# 8      Preto
# 9      Preto
# 10    Branco
# 12  Prateado
# 13  Prateado

# %%
#Caracterisitcas del dispositivos con el que el usuario visito el sitio
visitas = training_set.loc[:,['event','fecha','person','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']]
features_usuario = visitas.loc[visitas.event == 'visited site']
features_usuario.drop(['event'], inplace=True, axis=1)
features_usuario.head()
# Out:
#                  fecha    person new_vs_returning          region country  \
# 51 2018-05-23 19:52:31  0566e9c1        Returning  Rio de Janeiro  Brazil
# 52 2018-05-23 21:25:56  0566e9c1        Returning          Parana  Brazil
# 53 2018-05-24 11:29:03  0566e9c1        Returning          Parana  Brazil
# 54 2018-05-24 16:42:20  0566e9c1        Returning          Parana  Brazil
# 55 2018-05-25 20:59:09  0566e9c1        Returning          Parana  Brazil
#
#    device_type screen_resolution operating_system_version   browser_version
# 51  Smartphone           320x568                 iOS 11.3  Mobile Safari 11
# 52  Smartphone           320x568                 iOS 11.3  Mobile Safari 11
# 53  Smartphone           320x568                 iOS 11.3  Mobile Safari 11
# 54  Smartphone           320x568                 iOS 11.3  Mobile Safari 11
# 55  Smartphone           320x568                 iOS 11.3  Mobile Safari 11

# %%
productos_comprados.count()
# Out:
# fecha        36103
# person       36103
# sku              0
# model        36103
# condition    36103
# storage      36103
# color        36103
# dtype: int64

# %%
productos_visitados.count()
# Out:
# fecha        629233
# person       629233
# sku               0
# model        629233
# condition    629233
# storage      629233
# color        629233
# dtype: int64

# %%
features_usuario.count()
# Out:
# fecha                       102299
# person                      102299
# new_vs_returning            102299
# region                      102299
# country                     102299
# device_type                 102299
# screen_resolution           102297
# operating_system_version    102299
# browser_version             102299
# dtype: int64

# %%
del productos
del visitas

# %% [markdown]
# # Set de Datos de Entrenamiento

# %%
user_prod_comprados = productos_comprados.merge(features_usuario, on="person", how="inner")
user_prod_comprados.head()
# Out:
#               fecha_x    person  sku      model condition storage   color  \
# 0 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 1 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 2 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 3 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 4 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
#
#               fecha_y new_vs_returning          region country device_type  \
# 0 2018-05-23 19:52:31        Returning  Rio de Janeiro  Brazil  Smartphone
# 1 2018-05-23 21:25:56        Returning          Parana  Brazil  Smartphone
# 2 2018-05-24 11:29:03        Returning          Parana  Brazil  Smartphone
# 3 2018-05-24 16:42:20        Returning          Parana  Brazil  Smartphone
# 4 2018-05-25 20:59:09        Returning          Parana  Brazil  Smartphone
#
#   screen_resolution operating_system_version   browser_version
# 0           320x568                 iOS 11.3  Mobile Safari 11
# 1           320x568                 iOS 11.3  Mobile Safari 11
# 2           320x568                 iOS 11.3  Mobile Safari 11
# 3           320x568                 iOS 11.3  Mobile Safari 11
# 4           320x568                 iOS 11.3  Mobile Safari 11

# %%
user_prod_vistas = productos_visitados.merge(features_usuario, on="person", how="inner")
user_prod_vistas.head()
# Out:
#               fecha_x    person  sku      model  condition storage  color  \
# 0 2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G  Muito Bom    16GB  Preto
# 1 2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G  Muito Bom    16GB  Preto
# 2 2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G  Muito Bom    16GB  Preto
# 3 2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G  Muito Bom    16GB  Preto
# 4 2018-05-23 18:36:41  0566e9c1  NaN  iPhone 4G  Muito Bom    16GB  Preto
#
#               fecha_y new_vs_returning          region country device_type  \
# 0 2018-05-23 19:52:31        Returning  Rio de Janeiro  Brazil  Smartphone
# 1 2018-05-23 21:25:56        Returning          Parana  Brazil  Smartphone
# 2 2018-05-24 11:29:03        Returning          Parana  Brazil  Smartphone
# 3 2018-05-24 16:42:20        Returning          Parana  Brazil  Smartphone
# 4 2018-05-25 20:59:09        Returning          Parana  Brazil  Smartphone
#
#   screen_resolution operating_system_version   browser_version
# 0           320x568                 iOS 11.3  Mobile Safari 11
# 1           320x568                 iOS 11.3  Mobile Safari 11
# 2           320x568                 iOS 11.3  Mobile Safari 11
# 3           320x568                 iOS 11.3  Mobile Safari 11
# 4           320x568                 iOS 11.3  Mobile Safari 11

# %%
user_prod_comprados['person'].count()
# Out:
# 487040

# %%
user_prod_vistas['person'].count()
# Out:
# 15144663

# %%
del features_usuario
del productos_comprados
del productos_visitados

# %%
#concateno
# user_prod_comprados['label'] = 1
# user_prod_vistas['label'] = 0
frames = [user_prod_comprados, user_prod_vistas]
features = pd.concat(frames)
features.head()
# Out:
#               fecha_x    person  sku      model condition storage   color  \
# 0 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 1 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 2 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 3 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
# 4 2018-05-23 18:44:26  0566e9c1  NaN  iPhone 4S       Bom     8GB  Branco
#
#               fecha_y new_vs_returning          region country device_type  \
# 0 2018-05-23 19:52:31        Returning  Rio de Janeiro  Brazil  Smartphone
# 1 2018-05-23 21:25:56        Returning          Parana  Brazil  Smartphone
# 2 2018-05-24 11:29:03        Returning          Parana  Brazil  Smartphone
# 3 2018-05-24 16:42:20        Returning          Parana  Brazil  Smartphone
# 4 2018-05-25 20:59:09        Returning          Parana  Brazil  Smartphone
#
#   screen_resolution operating_system_version   browser_version
# 0           320x568                 iOS 11.3  Mobile Safari 11
# 1           320x568                 iOS 11.3  Mobile Safari 11
# 2           320x568                 iOS 11.3  Mobile Safari 11
# 3           320x568                 iOS 11.3  Mobile Safari 11
# 4           320x568                 iOS 11.3  Mobile Safari 11

# %%
del frames
del user_prod_comprados
del user_prod_vistas

# %%
features.count()
# Out:
# fecha_x                     15631703
# person                      15631703
# sku                                0
# model                       15631703
# condition                   15631703
# storage                     15631703
# color                       15631703
# fecha_y                     15631703
# new_vs_returning            15631703
# region                      15631703
# country                     15631703
# device_type                 15631703
# screen_resolution           15631559
# operating_system_version    15631703
# browser_version             15631703
# dtype: int64

# %%
features = features.fillna(value='')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-3f6c60015924> in <module>()
# ----> 1 features = features.fillna(value='')
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    3788                      self).fillna(value=value, method=method, axis=axis,
#    3789                                   inplace=inplace, limit=limit,
# -> 3790                                   downcast=downcast, **kwargs)
#    3791
#    3792     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5425                 new_data = self._data.fillna(value=value, limit=limit,
#    5426                                              inplace=inplace,
# -> 5427                                              downcast=downcast)
#    5428             elif isinstance(value, DataFrame) and self.ndim == 2:
#    5429                 new_data = self.where(self.notna(), value)
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/internals.py in fillna(self, **kwargs)
#    3706
#    3707     def fillna(self, **kwargs):
# -> 3708         return self.apply('fillna', **kwargs)
#    3709
#    3710     def downcast(self, **kwargs):
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3586         bm = self.__class__(result_blocks, axes or self.axes,
#    3587                             do_integrity_check=do_integrity_check)
# -> 3588         bm._consolidate_inplace()
#    3589         return bm
#    3590
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    4101     def _consolidate_inplace(self):
#    4102         if not self.is_consolidated():
# -> 4103             self.blocks = tuple(_consolidate(self.blocks))
#    4104             self._is_consolidated = True
#    4105             self._known_consolidated = True
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    5067     for (_can_consolidate, dtype), group_blocks in grouper:
#    5068         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 5069                                       _can_consolidate=_can_consolidate)
#    5070         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    5071     return new_blocks
#
# /home/agustin/.local/lib/python3.6/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    5090
#    5091         argsort = np.argsort(new_mgr_locs)
# -> 5092         new_values = new_values[argsort]
#    5093         new_mgr_locs = new_mgr_locs[argsort]
#    5094
#
# MemoryError:

# %% [markdown]
# ## Categorizacion de los features a entrenar

# %%
training_set = features 
del features

# %%
#Categorizamos los colores de 1 a n
training_set_list = training_set[['color']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
training_set[['color']] = training_set[['color']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos el estado del usuario 0 para new y 1 para returning
training_set[['new_vs_returning']] = training_set[['new_vs_returning']].applymap(lambda x: 0 if (x == 'New') else 1)

# %%
#Categorizamos los modelos de 1 a n
training_set_list = training_set[['model']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
training_set[['model']] = training_set[['model']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos las condiciones del producto de 1 a n
training_set_list = training_set[['condition']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
training_set[['condition']] = training_set[['condition']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos la capacidad de almacenamiento del producto de 1 a n
training_set_list = training_set[['storage']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
training_set[['storage']] = training_set[['storage']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos las regiones, paises y tipo de caracteristicas del usuario en un conjunto de 1 a n
training_set_list = training_set[['region','country','device_type','screen_resolution','operating_system_version','browser_version']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
training_set[['region','country','device_type','screen_resolution','operating_system_version','browser_version']] = training_set[['region','country','device_type','screen_resolution','operating_system_version','browser_version']].applymap(lambda x: diccionary[x])

# %%
del training_set_list
del diccionary
training_set.head()
# Out:
#               fecha_x    person      sku  model  condition  storage  color  \
# 0 2018-05-18 00:29:24  15ea8012  12802.0      1          1        1      1
# 1 2018-05-18 00:29:24  15ea8012  12802.0      1          1        1      1
# 2 2018-05-18 00:29:24  15ea8012  12802.0      1          1        1      1
# 3 2018-05-18 00:31:24  15ea8012  12788.0      1          1        1      2
# 4 2018-05-18 00:31:24  15ea8012  12788.0      1          1        1      2
#
#               fecha_y  new_vs_returning  region  country  device_type  \
# 0 2018-05-17 16:13:21                 0       1        2            3
# 1 2018-05-18 00:18:40                 1       1        2            3
# 2 2018-05-18 02:55:44                 1       1        2            3
# 3 2018-05-17 16:13:21                 0       1        2            3
# 4 2018-05-18 00:18:40                 1       1        2            3
#
#    screen_resolution  operating_system_version  browser_version  label
# 0                  4                         5                6      1
# 1                  4                         5                6      1
# 2                  4                         5                6      1
# 3                  4                         5                6      1
# 4                  4                         5                6      1

# %%
#Categorizamos la fecha del visto del producto en dia mes hora y minuto (ya que el anio es 2018)
training_set['dia_x'] = training_set['fecha_x'].apply(lambda x: x.day)
training_set['mes_x'] = training_set['fecha_x'].apply(lambda x: x.month)
training_set['hora_x'] = training_set['fecha_x'].apply(lambda x: x.hour)
training_set['minuto_x'] = training_set['fecha_x'].apply(lambda x: x.minute)
training_set = training_set.drop('fecha_x',1)

# %%
#Categorizamos la fecha de visita del usuario en dia mes hora y minuto (ya que el anio es 2018)
training_set['dia_y'] = training_set['fecha_y'].apply(lambda x: x.day)
training_set['mes_y'] = training_set['fecha_y'].apply(lambda x: x.month)
training_set['hora_y'] = training_set['fecha_y'].apply(lambda x: x.hour)
training_set['minuto_y'] = training_set['fecha_y'].apply(lambda x: x.minute)
training_set = training_set.drop('fecha_y',1)

# %%
training_set.head()
# Out:
#      person      sku  model  condition  storage  color  new_vs_returning  \
# 0  15ea8012  12802.0      1          1        1      1                 0
# 1  15ea8012  12802.0      1          1        1      1                 1
# 2  15ea8012  12802.0      1          1        1      1                 1
# 3  15ea8012  12788.0      1          1        1      2                 0
# 4  15ea8012  12788.0      1          1        1      2                 1
#
#    region  country  device_type    ...     browser_version  label  dia_x  \
# 0       1        2            3    ...                   6      1     18
# 1       1        2            3    ...                   6      1     18
# 2       1        2            3    ...                   6      1     18
# 3       1        2            3    ...                   6      1     18
# 4       1        2            3    ...                   6      1     18
#
#    mes_x  hora_x  minuto_x  dia_y  mes_y  hora_y  minuto_y
# 0      5       0        29     17      5      16        13
# 1      5       0        29     18      5       0        18
# 2      5       0        29     18      5       2        55
# 3      5       0        31     17      5      16        13
# 4      5       0        31     18      5       0        18
#
# [5 rows x 22 columns]

# %%
training_set.to_csv('data/set_entrenamiento.csv', encoding='utf-8', index=False)

# %%
training_set.tail()
# Out:
#             person      sku  model  condition  storage  color  \
# 29196626  300b0e1e   1302.0     10          3        4     11
# 29196627  300b0e1e   1302.0     10          3        4     11
# 29196628  300b0e1e  10882.0     44          2        3      3
# 29196629  300b0e1e  10882.0     44          2        3      3
# 29196630  9ce4b2a0   2725.0     54          2        4      5
#
#           new_vs_returning  region  country  device_type    ...     \
# 29196626                 0      21        2            3    ...
# 29196627                 1      21        2            3    ...
# 29196628                 0      21        2            3    ...
# 29196629                 1      21        2            3    ...
# 29196630                 0       1        2            3    ...
#
#           browser_version  label  dia_x  mes_x  hora_x  minuto_x  dia_y  \
# 29196626               35      0     15      3      21        27     15
# 29196627               35      0     15      3      21        27     16
# 29196628               35      0     15      3      21        23     15
# 29196629               35      0     15      3      21        23     16
# 29196630               48      0     20      2      12        33     20
#
#           mes_y  hora_y  minuto_y
# 29196626      3      21        16
# 29196627      3       1        32
# 29196628      3      21        16
# 29196629      3       1        32
# 29196630      2      12        32
#
# [5 rows x 22 columns]
