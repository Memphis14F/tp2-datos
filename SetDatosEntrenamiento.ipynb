# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from dateutil.parser import parse
import numpy as np

import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
events = pd.read_csv('data/events_up_to_01062018.csv')
events.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
events.count()
# Out:
# timestamp                   2341681
# event                       2341681
# person                      2341681
# url                          191131
# sku                         1320530
# model                       1321513
# condition                   1320530
# storage                     1320530
# color                       1320530
# skus                         505949
# search_term                  113763
# staticpage                    11201
# campaign_source              191286
# search_engine                106406
# channel                      204069
# new_vs_returning             204069
# city                         204069
# region                       204069
# country                      204069
# device_type                  204069
# screen_resolution            204066
# operating_system_version     204069
# browser_version              204069
# dtype: int64

# %% [markdown]
# # Analisis TP1

# %%
events.columns
# Out:
# Index(['timestamp', 'event', 'person', 'url', 'sku', 'model', 'condition',
#        'storage', 'color', 'skus', 'search_term', 'staticpage',
#        'campaign_source', 'search_engine', 'channel', 'new_vs_returning',
#        'city', 'region', 'country', 'device_type', 'screen_resolution',
#        'operating_system_version', 'browser_version'],
#       dtype='object')

# %%
events.drop(['url','sku','skus','city','search_engine','campaign_source','channel'], inplace=True, axis=1)

# %%
#Cambiamos el tipo de dato de fecha de timestamp a datetime para un mejor analisis y renombramos a "fecha"
events[['timestamp']] = events[['timestamp']].apply(pd.to_datetime)
events.rename({
    'timestamp' : 'fecha',
}, axis=1, inplace=True)
events.head()
# Out:
#                 fecha           event    person                    model  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  Samsung Galaxy J7 Prime
# 1 2018-05-18 00:11:27  viewed product  ad93850f                iPhone 5s
# 2 2018-05-18 00:11:16  viewed product  0297fc1e                iPhone 6S
# 3 2018-05-18 00:11:14  viewed product  2d681dd8                 iPhone 7
# 4 2018-05-18 00:11:09  viewed product  cccea85e              LG G4 H818P
#
#    condition storage           color search_term staticpage new_vs_returning  \
# 0  Excelente    32GB         Dourado         NaN        NaN              NaN
# 1  Muito Bom    32GB  Cinza espacial         NaN        NaN              NaN
# 2  Muito Bom    64GB        Prateado         NaN        NaN              NaN
# 3        Bom   128GB        Vermelho         NaN        NaN              NaN
# 4  Excelente    32GB          Branco         NaN        NaN              NaN
#
#   region country device_type screen_resolution operating_system_version  \
# 0    NaN     NaN         NaN               NaN                      NaN
# 1    NaN     NaN         NaN               NaN                      NaN
# 2    NaN     NaN         NaN               NaN                      NaN
# 3    NaN     NaN         NaN               NaN                      NaN
# 4    NaN     NaN         NaN               NaN                      NaN
#
#   browser_version
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
#Detalles de Productos que fueron comprados
productos = events.loc[:, ['event','fecha','person', 'model', 'condition', 'storage', 'color']]
productos_comprados = productos.loc[(productos.event == 'checkout') | (productos.event == 'conversion')]
productos_comprados.drop(['event'], inplace=True, axis=1)
productos_comprados.head()
# Out:
#                   fecha    person                             model  \
# 33  2018-05-18 00:29:24  15ea8012            Samsung Galaxy S8 Plus
# 60  2018-05-18 00:22:58  43790d8f             Motorola Moto G4 Plus
# 76  2018-05-18 00:38:51  d614c608                 Samsung Galaxy J5
# 133 2018-05-18 00:57:32  55d1e0ee  Samsung Galaxy Core Plus Duos TV
# 147 2018-05-18 01:12:43  bb78c182               Motorola Moto G3 4G
#
#      condition storage   color
# 33   Excelente    64GB   Prata
# 60         Bom    32GB   Bambu
# 76         Bom    16GB  Branco
# 133  Excelente     4GB   Preto
# 147        Bom    16GB   Preto

# %%
#Detalles de Productos que fueron visitados
productos_visitados = productos.loc[(productos.event == 'viewed product')]
productos_visitados.drop(['event'], inplace=True, axis=1)
productos_visitados.head()
# Out:
#                 fecha    person                    model  condition storage  \
# 0 2018-05-18 00:11:59  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1 2018-05-18 00:11:27  ad93850f                iPhone 5s  Muito Bom    32GB
# 2 2018-05-18 00:11:16  0297fc1e                iPhone 6S  Muito Bom    64GB
# 3 2018-05-18 00:11:14  2d681dd8                 iPhone 7        Bom   128GB
# 4 2018-05-18 00:11:09  cccea85e              LG G4 H818P  Excelente    32GB
#
#             color
# 0         Dourado
# 1  Cinza espacial
# 2        Prateado
# 3        Vermelho
# 4          Branco

# %%
#Caracterisitcas del dispositivos con el que el usuario visito el sitio
visitas = events.loc[:,['event','fecha','person','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']]
features_usuario = visitas.loc[visitas.event == 'visited site']
features_usuario.drop(['event'], inplace=True, axis=1)
features_usuario.head()
# Out:
#                       fecha    person new_vs_returning   region country  \
# 2136629 2018-05-10 22:34:50  4640420b        Returning   Parana  Brazil
# 2136630 2018-05-15 02:39:45  4640420b        Returning   Parana  Brazil
# 2136631 2018-05-18 01:15:26  4640420b        Returning  Unknown  Brazil
# 2136632 2018-05-18 19:03:37  4640420b        Returning   Parana  Brazil
# 2136633 2018-05-18 19:35:12  4640420b        Returning   Parana  Brazil
#
#         device_type screen_resolution operating_system_version  \
# 2136629  Smartphone           320x570            Android 5.0.2
# 2136630  Smartphone           320x570            Android 5.0.2
# 2136631    Computer         1280x1024                  Ubuntu
# 2136632      Tablet          800x1280                Android 7
# 2136633      Tablet          800x1280                Android 7
#
#             browser_version
# 2136629  Chrome Mobile 66.0
# 2136630  Chrome Mobile 66.0
# 2136631          Firefox 57
# 2136632         Chrome 66.0
# 2136633         Chrome 66.0

# %%
productos_comprados.count()
# Out:
# fecha        72406
# person       72406
# model        72406
# condition    72406
# storage      72406
# color        72406
# dtype: int64

# %%
productos_visitados.count()
# Out:
# fecha        1248124
# person       1248124
# model        1248124
# condition    1248124
# storage      1248124
# color        1248124
# dtype: int64

# %%
features_usuario.count()
# Out:
# fecha                       204069
# person                      204069
# new_vs_returning            204069
# region                      204069
# country                     204069
# device_type                 204069
# screen_resolution           204066
# operating_system_version    204069
# browser_version             204069
# dtype: int64

# %%
del events
del productos
del visitas

# %% [markdown]
# # Set de Datos de Entrenamiento

# %%
user_prod_comprados = productos_comprados.merge(features_usuario, on="person", how="inner")
user_prod_comprados.head()
# Out:
#               fecha_x    person                   model  condition storage  \
# 0 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 1 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 2 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 3 2018-05-18 00:31:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 4 2018-05-18 00:31:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
#
#       color             fecha_y new_vs_returning     region country  \
# 0     Prata 2018-05-17 16:13:21              New  Sao Paulo  Brazil
# 1     Prata 2018-05-18 00:18:40        Returning  Sao Paulo  Brazil
# 2     Prata 2018-05-18 02:55:44        Returning  Sao Paulo  Brazil
# 3  Ametista 2018-05-17 16:13:21              New  Sao Paulo  Brazil
# 4  Ametista 2018-05-18 00:18:40        Returning  Sao Paulo  Brazil
#
#   device_type screen_resolution operating_system_version     browser_version
# 0  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 1  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 2  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 3  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 4  Smartphone           360x640                Android 7  Chrome Mobile 66.0

# %%
user_prod_vistas = productos_visitados.merge(features_usuario, on="person", how="inner")
user_prod_vistas.head()
# Out:
#               fecha_x    person                    model  condition storage  \
# 0 2018-05-18 00:11:59  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1 2018-05-18 00:30:30  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 2 2018-05-18 00:11:35  4886f805  Samsung Galaxy J7 Prime  Muito Bom    32GB
# 3 2018-05-18 00:11:53  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 4 2018-05-18 00:11:27  ad93850f                iPhone 5s  Muito Bom    32GB
#
#             color             fecha_y new_vs_returning          region  \
# 0         Dourado 2018-05-18 00:07:22              New  Rio de Janeiro
# 1         Dourado 2018-05-18 00:07:22              New  Rio de Janeiro
# 2         Dourado 2018-05-18 00:07:22              New  Rio de Janeiro
# 3         Dourado 2018-05-18 00:07:22              New  Rio de Janeiro
# 4  Cinza espacial 2018-05-14 23:50:22              New       Sao Paulo
#
#   country device_type screen_resolution operating_system_version  \
# 0  Brazil  Smartphone           360x640                Android 7
# 1  Brazil  Smartphone           360x640                Android 7
# 2  Brazil  Smartphone           360x640                Android 7
# 3  Brazil  Smartphone           360x640                Android 7
# 4  Brazil  Smartphone           360x640            Android 5.1.1
#
#       browser_version
# 0  Chrome Mobile 64.0
# 1  Chrome Mobile 64.0
# 2  Chrome Mobile 64.0
# 3  Chrome Mobile 64.0
# 4  Chrome Mobile 66.0

# %%
del features_usuario
del productos_comprados
del productos_visitados

# %%
user_prod_comprados['person'].count()
# Out:
# 1050846

# %%
user_prod_comprados = user_prod_comprados.drop_duplicates()
user_prod_comprados['person'].count()
# Out:
# 1045740

# %%
user_prod_vistas['person'].count()
# Out:
# 29196631

# %%
user_prod_vistas = user_prod_vistas.drop_duplicates()
user_prod_vistas['person'].count()
# Out:
# 29122832

# %%
#concateno
# user_prod_comprados['label'] = 1
# user_prod_vistas['label'] = 0
frames = [user_prod_comprados, user_prod_vistas]
sets = pd.concat(frames)
sets.head()
# Out:
#               fecha_x    person                   model  condition storage  \
# 0 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 1 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 2 2018-05-18 00:29:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 3 2018-05-18 00:31:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
# 4 2018-05-18 00:31:24  15ea8012  Samsung Galaxy S8 Plus  Excelente    64GB
#
#       color             fecha_y new_vs_returning     region country  \
# 0     Prata 2018-05-17 16:13:21              New  Sao Paulo  Brazil
# 1     Prata 2018-05-18 00:18:40        Returning  Sao Paulo  Brazil
# 2     Prata 2018-05-18 02:55:44        Returning  Sao Paulo  Brazil
# 3  Ametista 2018-05-17 16:13:21              New  Sao Paulo  Brazil
# 4  Ametista 2018-05-18 00:18:40        Returning  Sao Paulo  Brazil
#
#   device_type screen_resolution operating_system_version     browser_version
# 0  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 1  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 2  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 3  Smartphone           360x640                Android 7  Chrome Mobile 66.0
# 4  Smartphone           360x640                Android 7  Chrome Mobile 66.0

# %%
del frames
del user_prod_comprados
del user_prod_vistas

# %%
sets.count()
# Out:
# fecha_x                     30168572
# person                      30168572
# model                       30168572
# condition                   30168572
# storage                     30168572
# color                       30168572
# fecha_y                     30168572
# new_vs_returning            30168572
# region                      30168572
# country                     30168572
# device_type                 30168572
# screen_resolution           30168417
# operating_system_version    30168572
# browser_version             30168572
# dtype: int64

# %%
sets = sets.fillna(value='')

# %% [markdown]
# ## Categorizacion de los features a entrenar

# %% [markdown]
# ### opcion 1: numeros para categorizar por feature (los numeros se repiten entre features)

# %%
#Categorizamos el estado del usuario 0 para new y 1 para returning
sets[['new_vs_returning']] = sets[['new_vs_returning']].applymap(lambda x: 0 if (x == 'New') else 1)

# %%
#Categorizamos los colores de 1 a n
training_set_list = sets[['color']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['color']] = sets[['color']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos los modelos de 1 a n
training_set_list = sets[['model']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['model']] = sets[['model']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos las condiciones del producto de 1 a n
training_set_list = sets[['condition']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['condition']] = sets[['condition']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos la capacidad de almacenamiento del producto de 1 a n
training_set_list = sets[['storage']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['storage']] = sets[['storage']].applymap(lambda x: diccionary[x])

# %%
#Categorizamos las regiones, paises y tipo de caracteristicas del usuario en un conjunto de 1 a n
training_set_list = sets[['new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']].values.tolist()
i=1
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['region','country','device_type','screen_resolution','operating_system_version','browser_version']] = sets[['region','country','device_type','screen_resolution','operating_system_version','browser_version']].applymap(lambda x: diccionary[x])

# %% [markdown]
# ### opcion 2: numeros para categorizar distintos por feature

# %%
#Categorizamos los features distintos de 61 (teniendo en cuenta el feature fecha-minuto) a n
training_set_list = sets[['model', 'condition', 'storage', 'color','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']].values.tolist()
i=61
diccionary={}

for lista in training_set_list:
    for element in lista:
        if type(element) != float:
            if element not in diccionary:
                diccionary[element]=i
                i+=1

# %%
sets[['model', 'condition', 'storage', 'color','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']] = sets[['model', 'condition', 'storage', 'color','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']].applymap(lambda x: diccionary[x])

# %%
del training_set_list
del diccionary
sets.head()
# Out:
#               fecha_x    person  model  condition  storage  color  \
# 0 2018-05-18 00:29:24  15ea8012     61         62       63     64
# 1 2018-05-18 00:29:24  15ea8012     61         62       63     64
# 2 2018-05-18 00:29:24  15ea8012     61         62       63     64
# 3 2018-05-18 00:31:24  15ea8012     61         62       63     73
# 4 2018-05-18 00:31:24  15ea8012     61         62       63     73
#
#               fecha_y  new_vs_returning  region  country  device_type  \
# 0 2018-05-17 16:13:21                65      66       67           68
# 1 2018-05-18 00:18:40                72      66       67           68
# 2 2018-05-18 02:55:44                72      66       67           68
# 3 2018-05-17 16:13:21                65      66       67           68
# 4 2018-05-18 00:18:40                72      66       67           68
#
#    screen_resolution  operating_system_version  browser_version
# 0                 69                        70               71
# 1                 69                        70               71
# 2                 69                        70               71
# 3                 69                        70               71
# 4                 69                        70               71

# %%
#Categorizamos la fecha del visto del producto en dia hora y minuto (ya que el anio es 2018)
sets['dia_view_prod'] = sets['fecha_x'].apply(lambda x: x.day)
sets['mes_view_prod'] = sets['fecha_x'].apply(lambda x: x.month)
sets['hora_view_prod'] = sets['fecha_x'].apply(lambda x: x.hour)
sets['minuto_view_prod'] = sets['fecha_x'].apply(lambda x: x.minute)
sets = sets.drop('fecha_x',1)

# %%
#Categorizamos la fecha de visita del usuario en dia mes hora y minuto (ya que el anio es 2018)
sets['dia_visit_user'] = sets['fecha_y'].apply(lambda x: x.day)
sets['mes_visit_user'] = sets['fecha_y'].apply(lambda x: x.month)
sets['hora_visit_user'] = sets['fecha_y'].apply(lambda x: x.hour)
sets['minuto_visit_user'] = sets['fecha_y'].apply(lambda x: x.minute)
sets = sets.drop('fecha_y',1)

# %%
sets.head()
# Out:
#      person  model  condition  storage  color  new_vs_returning  region  \
# 0  15ea8012     61         62       63     64                65      66
# 1  15ea8012     61         62       63     64                72      66
# 2  15ea8012     61         62       63     64                72      66
# 3  15ea8012     61         62       63     73                65      66
# 4  15ea8012     61         62       63     73                72      66
#
#    country  device_type  screen_resolution  operating_system_version  \
# 0       67           68                 69                        70
# 1       67           68                 69                        70
# 2       67           68                 69                        70
# 3       67           68                 69                        70
# 4       67           68                 69                        70
#
#    browser_version  dia_view_prod  mes_view_prod  hora_view_prod  \
# 0               71             18              5               0
# 1               71             18              5               0
# 2               71             18              5               0
# 3               71             18              5               0
# 4               71             18              5               0
#
#    minuto_view_prod  dia_visit_user  mes_visit_user  hora_visit_user  \
# 0                29              17               5               16
# 1                29              18               5                0
# 2                29              18               5                2
# 3                31              17               5               16
# 4                31              18               5                0
#
#    minuto_visit_user
# 0                 13
# 1                 18
# 2                 55
# 3                 13
# 4                 18

# %%
sets.tail()
# Out:
#             person  model  condition  storage  color  new_vs_returning  \
# 29196626  300b0e1e    111         97       83    122                65
# 29196627  300b0e1e    111         97       83    122                72
# 29196628  300b0e1e    200         75       79     77                65
# 29196629  300b0e1e    200         75       79     77                72
# 29196630  9ce4b2a0    236         75       83     84                65
#
#           region  country  device_type  screen_resolution  \
# 29196626     106       67           68                 69
# 29196627     106       67           68                 69
# 29196628     106       67           68                 69
# 29196629     106       67           68                 69
# 29196630      66       67           68                190
#
#           operating_system_version  browser_version  dia_view_prod  \
# 29196626                       140              134             15
# 29196627                       140              134             15
# 29196628                       140              134             15
# 29196629                       140              134             15
# 29196630                        81              150             20
#
#           mes_view_prod  hora_view_prod  minuto_view_prod  dia_visit_user  \
# 29196626              3              21                27              15
# 29196627              3              21                27              16
# 29196628              3              21                23              15
# 29196629              3              21                23              16
# 29196630              2              12                33              20
#
#           mes_visit_user  hora_visit_user  minuto_visit_user
# 29196626               3               21                 16
# 29196627               3                1                 32
# 29196628               3               21                 16
# 29196629               3                1                 32
# 29196630               2               12                 32

# %% [markdown]
# # Separamos los set de entrenamiento y prediccion

# %%
label_training = pd.read_csv('data/labels_training_set.csv')
label_training.head()
# Out:
#      person  label
# 0  0566e9c1      0
# 1  6ec7ee77      0
# 2  abe7a2fb      0
# 3  34728364      0
# 4  87ed62de      0

# %%
# Set prediccion son los que NO estan en labels_training y pero SI en events_up_to_01062018
prediction_set = sets.merge(label_training, how= 'left', on = 'person')
prediction_set = prediction_set[prediction_set.label.isnull()]
prediction_set.drop('label', inplace=True, axis=1)
prediction_set.count()
# Out:
# person                      14571225
# model                       14571225
# condition                   14571225
# storage                     14571225
# color                       14571225
# new_vs_returning            14571225
# region                      14571225
# country                     14571225
# device_type                 14571225
# screen_resolution           14571225
# operating_system_version    14571225
# browser_version             14571225
# dia_view_prod               14571225
# mes_view_prod               14571225
# hora_view_prod              14571225
# minuto_view_prod            14571225
# dia_visit_user              14571225
# mes_visit_user              14571225
# hora_visit_user             14571225
# minuto_visit_user           14571225
# dtype: int64

# %%
prediction_set.to_csv('data/set_prediccion_2.csv', encoding='utf-8', index=False)

# %%
# Set entrenamiento son los que estan en labels_training y events_up_to_01062018
training_set = sets.merge(label_training, how= 'inner', on = 'person')
training_set.count()
# Out:
# person                      15597347
# model                       15597347
# condition                   15597347
# storage                     15597347
# color                       15597347
# new_vs_returning            15597347
# region                      15597347
# country                     15597347
# device_type                 15597347
# screen_resolution           15597347
# operating_system_version    15597347
# browser_version             15597347
# dia_view_prod               15597347
# mes_view_prod               15597347
# hora_view_prod              15597347
# minuto_view_prod            15597347
# dia_visit_user              15597347
# mes_visit_user              15597347
# hora_visit_user             15597347
# minuto_visit_user           15597347
# label                       15597347
# dtype: int64

# %%
training_set[training_set['label'] == 1].shape
# Out:
# (1630594, 21)

# %%
training_set[training_set['label'] == 0].shape
# Out:
# (13966753, 21)

# %%
training_set.to_csv('data/set_entrenamiento_2.csv', encoding='utf-8', index=False)
