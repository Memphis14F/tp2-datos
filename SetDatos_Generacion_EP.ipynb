# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from dateutil.parser import parse
import numpy as np

import warnings
import datetime as dt
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
events = pd.read_csv('data/events_up_to_01062018.csv', low_memory = False)
events.person.describe()
# Out:
# count      2341681
# unique       38829
# top       c76b8417
# freq          4438
# Name: person, dtype: object

# %%
prediction_set = pd.read_csv('data/trocafone_kaggle_test.csv', low_memory = False)
training_set = pd.read_csv('data/labels_training_set.csv', low_memory=False)

print('PREDICCION ' , prediction_set.person.describe())
print('ENTRENAMIENTO ', training_set.person.describe())
print('ENTRENAMIENTO 1s ', training_set[training_set['label'] == 1].shape)
print('ENTRENAMIENTO 0s ', training_set[training_set['label'] == 0].shape)

prediction_set = prediction_set.merge(events, on = 'person', how = 'inner')
prediction_set = prediction_set[(prediction_set['event'] == 'visited site') | (prediction_set['event'] == 'viewed product') | (prediction_set['event'] == 'conversion') | (prediction_set['event'] == 'checkout') | (prediction_set['event'] == 'brand listing') | (prediction_set['event'] == 'generic listing') | (prediction_set['event'] == 'lead') | (prediction_set['event'] == 'staticpage') ]                                                                       

training_set = events.merge(training_set, on = 'person', how = 'inner')

# info = training_set[['person']]
# info['frecuencia'] = 1
# data = pd.DataFrame({'frecuencia': info.groupby('person').aggregate(sum)['frecuencia']}).reset_index()

# training_set = training_set.merge(data, on = 'person', how = 'left')
# training_set= training_set[(training_set['label'] == 1) | ((training_set['frecuencia'] <= 200) & (training_set['label'] == 0))]
# Out:
# PREDICCION  count        19415
# unique       19415
# top       c6ab1bc3
# freq             1
# Name: person, dtype: object
# ENTRENAMIENTO  count        19414
# unique       19414
# top       1836c63e
# freq             1
# Name: person, dtype: object
# ENTRENAMIENTO 1s  (980, 2)
# ENTRENAMIENTO 0s  (18434, 2)

# %%
# del info
# del data
del events

# %%
prediction_set.person.describe()
# Out:
# count       953099
# unique       19415
# top       5059f7fd
# freq          2932
# Name: person, dtype: object

# %%
training_set.person.describe()
# Out:
# count      1171886
# unique       19414
# top       ffee0f18
# freq          3458
# Name: person, dtype: object

# %% [markdown]
# # Set Datos Prediccion

# %% [markdown]
# ## Analisis TP1

# %%
prediction_set.columns
# Out:
# Index(['person', 'timestamp', 'event', 'url', 'sku', 'model', 'condition',
#        'storage', 'color', 'skus', 'search_term', 'staticpage',
#        'campaign_source', 'search_engine', 'channel', 'new_vs_returning',
#        'city', 'region', 'country', 'device_type', 'screen_resolution',
#        'operating_system_version', 'browser_version'],
#       dtype='object')

# %%
prediction_set.drop(['url','skus', 'sku', 'city','search_engine','campaign_source','channel'], inplace=True, axis=1)

# %%
#Cambiamos el tipo de dato de fecha de timestamp a datetime para un mejor analisis y renombramos a "fecha"
prediction_set[['timestamp']] = prediction_set[['timestamp']].apply(pd.to_datetime)
prediction_set.rename({
    'timestamp' : 'fecha',
}, axis=1, inplace=True)
prediction_set.head()
# Out:
#      person               fecha           event                    model  \
# 0  4886f805 2018-05-18 00:11:59  viewed product  Samsung Galaxy J7 Prime
# 1  4886f805 2018-05-18 00:30:30  viewed product  Samsung Galaxy J7 Prime
# 3  4886f805 2018-05-18 00:11:56        checkout  Samsung Galaxy J7 Prime
# 4  4886f805 2018-05-18 00:11:35  viewed product  Samsung Galaxy J7 Prime
# 6  4886f805 2018-05-18 00:11:53  viewed product  Samsung Galaxy J7 Prime
#
#    condition storage    color search_term staticpage new_vs_returning region  \
# 0  Excelente    32GB  Dourado         NaN        NaN              NaN    NaN
# 1  Excelente    32GB  Dourado         NaN        NaN              NaN    NaN
# 3  Excelente    32GB  Dourado         NaN        NaN              NaN    NaN
# 4  Muito Bom    32GB  Dourado         NaN        NaN              NaN    NaN
# 6  Excelente    32GB  Dourado         NaN        NaN              NaN    NaN
#
#   country device_type screen_resolution operating_system_version  \
# 0     NaN         NaN               NaN                      NaN
# 1     NaN         NaN               NaN                      NaN
# 3     NaN         NaN               NaN                      NaN
# 4     NaN         NaN               NaN                      NaN
# 6     NaN         NaN               NaN                      NaN
#
#   browser_version
# 0             NaN
# 1             NaN
# 3             NaN
# 4             NaN
# 6             NaN

# %% [markdown]
# vamos a crear las columnas compras_prod, vistas_prod, otros para productos y visitas_sitio para persona, de la forma de One Hot Encoder

# %%
#Detalles de Productos que fueron comprados
productos = prediction_set.loc[:, ['event','fecha','person', 'model', 'condition', 'storage', 'color']]
productos_comprados = productos[(productos['event'] == 'conversion') | (productos['event'] == 'checkout')]
productos_comprados.drop(['event'], inplace=True, axis=1)
productos_comprados['compras_prod'] = 1
productos_comprados['vistas_prod'] = 0
productos_comprados['otros'] = 0
productos_comprados.head()
# Out:
#                   fecha    person                    model  condition storage  \
# 3   2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 56  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 89  2018-05-10 00:39:51  0297fc1e           iPhone 6S Plus        Bom    16GB
# 313 2018-02-25 18:38:00  0297fc1e                 iPhone 6  Muito Bom    64GB
# 339 2018-01-31 16:12:48  0297fc1e                 iPhone 6        Bom    64GB
#
#               color  compras_prod  vistas_prod  otros
# 3           Dourado             1            0      0
# 56        Ouro Rosa             1            0      0
# 89   Cinza espacial             1            0      0
# 313         Dourado             1            0      0
# 339         Dourado             1            0      0

# %%
productos_comprados.count()
# Out:
# fecha           36303
# person          36303
# model           36303
# condition       36303
# storage         36303
# color           36303
# compras_prod    36303
# vistas_prod     36303
# otros           36303
# dtype: int64

# %%
# productos_comprados = productos_comprados.drop_duplicates()
# productos_comprados.count()

# %%
#Detalles de Productos que fueron visitados
productos_visitados = productos.loc[productos.event == 'viewed product']
productos_visitados.drop(['event'], inplace=True, axis=1)
productos_visitados['compras_prod'] = 0
productos_visitados['vistas_prod'] = 1
productos_visitados['otros'] = 0
productos_visitados.head()
# Out:
#                 fecha    person                    model  condition storage  \
# 0 2018-05-18 00:11:59  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1 2018-05-18 00:30:30  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 4 2018-05-18 00:11:35  4886f805  Samsung Galaxy J7 Prime  Muito Bom    32GB
# 6 2018-05-18 00:11:53  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 9 2018-05-18 00:11:16  0297fc1e                iPhone 6S  Muito Bom    64GB
#
#       color  compras_prod  vistas_prod  otros
# 0   Dourado             0            1      0
# 1   Dourado             0            1      0
# 4   Dourado             0            1      0
# 6   Dourado             0            1      0
# 9  Prateado             0            1      0

# %%
productos_visitados.count()
# Out:
# fecha           618891
# person          618891
# model           618891
# condition       618891
# storage         618891
# color           618891
# compras_prod    618891
# vistas_prod     618891
# otros           618891
# dtype: int64

# %%
# productos_visitados = productos_visitados.drop_duplicates()
# productos_visitados.count()

# %%
# Eliminamos de productos visitados las personas que estan en productos comprados
productos_visitados = productos_visitados.merge(productos_comprados, on='person', how='left')
productos_visitados = productos_visitados[productos_visitados['fecha_y'].isnull()]
productos_visitados = productos_visitados.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x']]
productos_visitados.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros'}, inplace=True)
productos_visitados.head()
# Out:
#                    fecha    person      model  condition storage        color  \
# 6574 2018-05-18 00:25:42  686c49c9   iPhone 7  Excelente   128GB    Ouro Rosa
# 6575 2018-05-18 00:25:27  686c49c9   iPhone 7  Excelente   128GB  Preto Matte
# 6576 2018-05-18 01:05:31  686c49c9   iPhone 7  Excelente   128GB    Ouro Rosa
# 6577 2018-05-15 20:11:48  686c49c9   iPhone 7  Excelente   128GB     Prateado
# 6578 2018-05-15 20:10:28  686c49c9  iPhone 6S  Excelente    16GB      Dourado
#
#       compras_prod  vistas_prod  otros
# 6574             0            1      0
# 6575             0            1      0
# 6576             0            1      0
# 6577             0            1      0
# 6578             0            1      0

# %%
productos_visitados.count()
# Out:
# fecha           58106
# person          58106
# model           58106
# condition       58106
# storage         58106
# color           58106
# compras_prod    58106
# vistas_prod     58106
# otros           58106
# dtype: int64

# %%
otros = prediction_set.loc[:, ['event','fecha','person', 'model', 'condition', 'storage', 'color']]
otros = otros[(otros['event'] == 'brand listing') | (otros['event'] == 'generic listing') | (otros['event'] == 'lead') | (otros['event'] == 'staticpage')]
otros.drop(['event'], inplace=True, axis=1)
otros['compras_prod'] = 0
otros['vistas_prod'] = 0
otros['otros'] = 1
otros.head()
# Out:
#                   fecha    person model condition storage color  compras_prod  \
# 7   2018-05-18 00:07:22  4886f805   NaN       NaN     NaN   NaN             0
# 455 2018-05-17 19:59:37  0297fc1e   NaN       NaN     NaN   NaN             0
# 456 2018-05-21 23:08:54  0297fc1e   NaN       NaN     NaN   NaN             0
# 457 2018-03-20 16:39:59  0297fc1e   NaN       NaN     NaN   NaN             0
# 458 2018-04-29 18:41:44  0297fc1e   NaN       NaN     NaN   NaN             0
#
#      vistas_prod  otros
# 7              0      1
# 455            0      1
# 456            0      1
# 457            0      1
# 458            0      1

# %%
otros.count()
# Out:
# fecha           196135
# person          196135
# model              552
# condition            0
# storage              0
# color                0
# compras_prod    196135
# vistas_prod     196135
# otros           196135
# dtype: int64

# %%
# otros = otros.drop_duplicates()
# otros.count()

# %%
# Eliminamos de otros las personas que estan en productos comprados
otros = otros.merge(productos_comprados, on='person', how='left')
otros = otros[otros['fecha_y'].isnull()]
otros = otros.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x']]
otros.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros'}, inplace=True)
otros.head()
# Out:
#                   fecha    person model condition storage color  compras_prod  \
# 523 2018-05-07 12:45:15  686c49c9   NaN       NaN     NaN   NaN             0
# 524 2018-05-07 12:39:53  686c49c9   NaN       NaN     NaN   NaN             0
# 525 2018-05-07 12:41:38  686c49c9   NaN       NaN     NaN   NaN             0
# 526 2018-05-07 12:43:42  686c49c9   NaN       NaN     NaN   NaN             0
# 527 2018-05-07 12:43:43  686c49c9   NaN       NaN     NaN   NaN             0
#
#      vistas_prod  otros
# 523            0      1
# 524            0      1
# 525            0      1
# 526            0      1
# 527            0      1

# %%
otros.count()
# Out:
# fecha           18472
# person          18472
# model              58
# condition           0
# storage             0
# color               0
# compras_prod    18472
# vistas_prod     18472
# otros           18472
# dtype: int64

# %%
# Eliminamos de otros las personas que estan en productos visitados
otros = otros.merge(productos_visitados, on='person', how='left')
otros = otros[otros['fecha_y'].isnull()]
otros = otros.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x']]
otros.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros'}, inplace=True)
otros.head()
# Out:
#                     fecha    person model condition storage color  \
# 60413 2018-05-28 12:36:14  df80a783   NaN       NaN     NaN   NaN
# 60414 2018-05-28 22:28:24  df80a783   NaN       NaN     NaN   NaN
# 60415 2018-05-29 14:47:28  df80a783   NaN       NaN     NaN   NaN
# 63146 2018-05-19 16:30:03  5437de8d   NaN       NaN     NaN   NaN
# 69477 2018-02-07 13:52:08  626d2cd6   NaN       NaN     NaN   NaN
#
#        compras_prod  vistas_prod  otros
# 60413             0            0      1
# 60414             0            0      1
# 60415             0            0      1
# 63146             0            0      1
# 69477             0            0      1

# %%
otros.count()
# Out:
# fecha           590
# person          590
# model             5
# condition         0
# storage           0
# color             0
# compras_prod    590
# vistas_prod     590
# otros           590
# dtype: int64

# %%
#Caracterisitcas del dispositivos con el que el usuario visito el sitio
visitas = prediction_set.loc[:,['event','fecha','person','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version']]
features_usuario = visitas.loc[visitas.event == 'visited site']
features_usuario.drop(['event'], inplace=True, axis=1)
features_usuario['visitas_sitio'] = 1
features_usuario.head()
# Out:
#                   fecha    person new_vs_returning          region country  \
# 8   2018-05-18 00:07:22  4886f805              New  Rio de Janeiro  Brazil
# 480 2018-05-02 01:28:27  0297fc1e        Returning  Rio de Janeiro  Brazil
# 481 2018-05-02 14:28:20  0297fc1e        Returning  Rio de Janeiro  Brazil
# 482 2018-05-03 01:55:52  0297fc1e        Returning  Rio de Janeiro  Brazil
# 483 2018-05-10 00:38:17  0297fc1e        Returning  Rio de Janeiro  Brazil
#
#     device_type screen_resolution operating_system_version  \
# 8    Smartphone           360x640                Android 7
# 480  Smartphone           360x640            Android 6.0.1
# 481  Smartphone           360x640            Android 6.0.1
# 482  Smartphone           360x640            Android 6.0.1
# 483  Smartphone           360x640            Android 6.0.1
#
#         browser_version  visitas_sitio
# 8    Chrome Mobile 64.0              1
# 480  Chrome Mobile 65.0              1
# 481  Chrome Mobile 65.0              1
# 482  Chrome Mobile 65.0              1
# 483  Chrome Mobile 65.0              1

# %%
features_usuario.count()
# Out:
# fecha                       101770
# person                      101770
# new_vs_returning            101770
# region                      101770
# country                     101770
# device_type                 101770
# screen_resolution           101769
# operating_system_version    101770
# browser_version             101770
# visitas_sitio               101770
# dtype: int64

# %%
features_usuario = features_usuario.drop_duplicates()
features_usuario.count()
# Out:
# fecha                       101770
# person                      101770
# new_vs_returning            101770
# region                      101770
# country                     101770
# device_type                 101770
# screen_resolution           101769
# operating_system_version    101770
# browser_version             101770
# visitas_sitio               101770
# dtype: int64

# %%
del productos
del visitas

# %%
user_prod_comprados = productos_comprados.merge(features_usuario, on="person", how="outer")
user_prod_comprados.head()
# Out:
#               fecha_x    person                    model  condition storage  \
# 0 2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros             fecha_y  \
# 0    Dourado           1.0          0.0    0.0 2018-05-18 00:07:22
# 1  Ouro Rosa           1.0          0.0    0.0 2018-05-02 01:28:27
# 2  Ouro Rosa           1.0          0.0    0.0 2018-05-02 14:28:20
# 3  Ouro Rosa           1.0          0.0    0.0 2018-05-03 01:55:52
# 4  Ouro Rosa           1.0          0.0    0.0 2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio
# 0                Android 7  Chrome Mobile 64.0            1.0
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0

# %%
user_prod_comprados.count()
# Out:
# fecha_x                     564204
# person                      575085
# model                       564204
# condition                   564204
# storage                     564204
# color                       564204
# compras_prod                564204
# vistas_prod                 564204
# otros                       564204
# fecha_y                     574687
# new_vs_returning            574687
# region                      574687
# country                     574687
# device_type                 574687
# screen_resolution           574686
# operating_system_version    574687
# browser_version             574687
# visitas_sitio               574687
# dtype: int64

# %%
user_prod_vistas = productos_visitados.merge(features_usuario, on="person", how="outer")
user_prod_vistas.head()
# Out:
#               fecha_x    person     model  condition storage      color  \
# 0 2018-05-18 00:25:42  686c49c9  iPhone 7  Excelente   128GB  Ouro Rosa
# 1 2018-05-18 00:25:42  686c49c9  iPhone 7  Excelente   128GB  Ouro Rosa
# 2 2018-05-18 00:25:42  686c49c9  iPhone 7  Excelente   128GB  Ouro Rosa
# 3 2018-05-18 00:25:42  686c49c9  iPhone 7  Excelente   128GB  Ouro Rosa
# 4 2018-05-18 00:25:42  686c49c9  iPhone 7  Excelente   128GB  Ouro Rosa
#
#    compras_prod  vistas_prod  otros             fecha_y new_vs_returning  \
# 0           0.0          1.0    0.0 2018-05-07 12:39:52              New
# 1           0.0          1.0    0.0 2018-05-07 12:43:42        Returning
# 2           0.0          1.0    0.0 2018-05-15 20:07:26        Returning
# 3           0.0          1.0    0.0 2018-05-18 00:21:05        Returning
# 4           0.0          1.0    0.0 2018-05-18 01:05:32        Returning
#
#       region country device_type screen_resolution operating_system_version  \
# 0  Sao Paulo  Brazil  Smartphone           320x568               iOS 10.3.3
# 1  Sao Paulo  Brazil  Smartphone           320x568               iOS 10.3.3
# 2  Sao Paulo  Brazil  Smartphone           320x568               iOS 10.3.3
# 3  Sao Paulo  Brazil  Smartphone           320x568               iOS 10.3.3
# 4  Sao Paulo  Brazil  Smartphone           320x568               iOS 10.3.3
#
#     browser_version  visitas_sitio
# 0  Mobile Safari 10            1.0
# 1  Mobile Safari 10            1.0
# 2  Mobile Safari 10            1.0
# 3  Mobile Safari 10            1.0
# 4  Mobile Safari 10            1.0

# %%
user_prod_vistas.count()
# Out:
# fecha_x                     627953
# person                      719287
# model                       627953
# condition                   627953
# storage                     627953
# color                       627953
# compras_prod                627953
# vistas_prod                 627953
# otros                       627953
# fecha_y                     719260
# new_vs_returning            719260
# region                      719260
# country                     719260
# device_type                 719260
# screen_resolution           719259
# operating_system_version    719260
# browser_version             719260
# visitas_sitio               719260
# dtype: int64

# %%
otros = otros.merge(features_usuario, on="person", how="outer")
otros.head()
# Out:
#               fecha_x    person model condition storage color  compras_prod  \
# 0 2018-05-28 12:36:14  df80a783   NaN       NaN     NaN   NaN           0.0
# 1 2018-05-28 12:36:14  df80a783   NaN       NaN     NaN   NaN           0.0
# 2 2018-05-28 12:36:14  df80a783   NaN       NaN     NaN   NaN           0.0
# 3 2018-05-28 12:36:14  df80a783   NaN       NaN     NaN   NaN           0.0
# 4 2018-05-28 22:28:24  df80a783   NaN       NaN     NaN   NaN           0.0
#
#    vistas_prod  otros             fecha_y new_vs_returning        region  \
# 0          0.0    1.0 2018-05-28 12:36:14              New      Maranhao
# 1          0.0    1.0 2018-05-28 22:28:25        Returning  Minas Gerais
# 2          0.0    1.0 2018-05-29 14:47:28        Returning         Piaui
# 3          0.0    1.0 2018-05-29 17:00:15        Returning         Piaui
# 4          0.0    1.0 2018-05-28 12:36:14              New      Maranhao
#
#   country device_type screen_resolution operating_system_version  \
# 0  Brazil  Smartphone           360x640            Android 5.1.1
# 1  Brazil  Smartphone           360x640            Android 5.1.1
# 2  Brazil  Smartphone           360x640            Android 5.1.1
# 3  Brazil  Smartphone           360x640            Android 5.1.1
# 4  Brazil  Smartphone           360x640            Android 5.1.1
#
#         browser_version  visitas_sitio
# 0  Samsung Internet 6.4            1.0
# 1  Samsung Internet 6.4            1.0
# 2  Samsung Internet 6.4            1.0
# 3  Samsung Internet 6.4            1.0
# 4  Samsung Internet 6.4            1.0

# %%
otros.count()
# Out:
# fecha_x                       3877
# person                      105273
# model                            5
# condition                        0
# storage                          0
# color                            0
# compras_prod                  3877
# vistas_prod                   3877
# otros                         3877
# fecha_y                     105260
# new_vs_returning            105260
# region                      105260
# country                     105260
# device_type                 105260
# screen_resolution           105259
# operating_system_version    105260
# browser_version             105260
# visitas_sitio               105260
# dtype: int64

# %%
del features_usuario
del productos_comprados
del productos_visitados

# %%
#concateno
frames = [user_prod_comprados, user_prod_vistas, otros]
sets = pd.concat(frames)
sets.head()
# Out:
#               fecha_x    person                    model  condition storage  \
# 0 2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4 2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros             fecha_y  \
# 0    Dourado           1.0          0.0    0.0 2018-05-18 00:07:22
# 1  Ouro Rosa           1.0          0.0    0.0 2018-05-02 01:28:27
# 2  Ouro Rosa           1.0          0.0    0.0 2018-05-02 14:28:20
# 3  Ouro Rosa           1.0          0.0    0.0 2018-05-03 01:55:52
# 4  Ouro Rosa           1.0          0.0    0.0 2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio
# 0                Android 7  Chrome Mobile 64.0            1.0
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0

# %%
del frames
del user_prod_comprados
del user_prod_vistas
del otros

# %%
sets = sets.drop_duplicates()

# %%
sets.count()
# Out:
# fecha_x                     1192107
# person                      1293877
# model                       1188257
# condition                   1188252
# storage                     1188252
# color                       1188252
# compras_prod                1192107
# vistas_prod                 1192107
# otros                       1192107
# fecha_y                     1293439
# new_vs_returning            1293439
# region                      1293439
# country                     1293439
# device_type                 1293439
# screen_resolution           1293437
# operating_system_version    1293439
# browser_version             1293439
# visitas_sitio               1293439
# dtype: int64

# %%
# Rellenamos compras_prod  vistas_prod  otros y visitas_sitio con 0
sets['compras_prod'] = sets['compras_prod'].fillna(value=0) 
sets['vistas_prod'] = sets['vistas_prod'].fillna(value=0) 
sets['otros'] = sets['otros'].fillna(value=0) 
sets['visitas_sitio'] = sets['visitas_sitio'].fillna(value=0)

# %%
sets.count()
# Out:
# fecha_x                     1192107
# person                      1293877
# model                       1188257
# condition                   1188252
# storage                     1188252
# color                       1188252
# compras_prod                1293877
# vistas_prod                 1293877
# otros                       1293877
# fecha_y                     1293439
# new_vs_returning            1293439
# region                      1293439
# country                     1293439
# device_type                 1293439
# screen_resolution           1293437
# operating_system_version    1293439
# browser_version             1293439
# visitas_sitio               1293877
# dtype: int64

# %%
# Rellenamos los demas con ''
sets = sets.fillna(value='')

# %%
sets.count()
# Out:
# fecha_x                     1293877
# person                      1293877
# model                       1293877
# condition                   1293877
# storage                     1293877
# color                       1293877
# compras_prod                1293877
# vistas_prod                 1293877
# otros                       1293877
# fecha_y                     1293877
# new_vs_returning            1293877
# region                      1293877
# country                     1293877
# device_type                 1293877
# screen_resolution           1293877
# operating_system_version    1293877
# browser_version             1293877
# visitas_sitio               1293877
# dtype: int64

# %%
sets.person.describe()
# Out:
# count      1293877
# unique       19415
# top       5059f7fd
# freq         96465
# Name: person, dtype: object

# %% [markdown]
# ## Categorizacion de los features

# %%
# creo una nueva columna person_int para entrenar transformando el valor alfanumerico de person a numerico
sets['person_int'] = labelencoder.fit_transform(sets['person'])
sets.head()
# Out:
#                fecha_x    person                    model  condition storage  \
# 0  2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros              fecha_y  \
# 0    Dourado           1.0          0.0    0.0  2018-05-18 00:07:22
# 1  Ouro Rosa           1.0          0.0    0.0  2018-05-02 01:28:27
# 2  Ouro Rosa           1.0          0.0    0.0  2018-05-02 14:28:20
# 3  Ouro Rosa           1.0          0.0    0.0  2018-05-03 01:55:52
# 4  Ouro Rosa           1.0          0.0    0.0  2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio  person_int
# 0                Android 7  Chrome Mobile 64.0            1.0        5476
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0         189

# %%
# convertimos a integer el valor flotante de compras_prod
sets['compras_prod'] = sets['compras_prod'].astype('int')
sets.head()
# Out:
#                fecha_x    person                    model  condition storage  \
# 0  2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros              fecha_y  \
# 0    Dourado             1          0.0    0.0  2018-05-18 00:07:22
# 1  Ouro Rosa             1          0.0    0.0  2018-05-02 01:28:27
# 2  Ouro Rosa             1          0.0    0.0  2018-05-02 14:28:20
# 3  Ouro Rosa             1          0.0    0.0  2018-05-03 01:55:52
# 4  Ouro Rosa             1          0.0    0.0  2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio  person_int
# 0                Android 7  Chrome Mobile 64.0            1.0        5476
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0         189

# %%
# convertimos a integer el valor flotante de vistas_prod
sets['vistas_prod'] = sets['vistas_prod'].astype('int')
sets.head()
# Out:
#                fecha_x    person                    model  condition storage  \
# 0  2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros              fecha_y  \
# 0    Dourado             1            0    0.0  2018-05-18 00:07:22
# 1  Ouro Rosa             1            0    0.0  2018-05-02 01:28:27
# 2  Ouro Rosa             1            0    0.0  2018-05-02 14:28:20
# 3  Ouro Rosa             1            0    0.0  2018-05-03 01:55:52
# 4  Ouro Rosa             1            0    0.0  2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio  person_int
# 0                Android 7  Chrome Mobile 64.0            1.0        5476
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0         189

# %%
# convertimos a integer el valor flotante de otros
sets['otros'] = sets['otros'].astype('int')
sets.head()
# Out:
#                fecha_x    person                    model  condition storage  \
# 0  2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros              fecha_y  \
# 0    Dourado             1            0      0  2018-05-18 00:07:22
# 1  Ouro Rosa             1            0      0  2018-05-02 01:28:27
# 2  Ouro Rosa             1            0      0  2018-05-02 14:28:20
# 3  Ouro Rosa             1            0      0  2018-05-03 01:55:52
# 4  Ouro Rosa             1            0      0  2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio  person_int
# 0                Android 7  Chrome Mobile 64.0            1.0        5476
# 1            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 2            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 3            Android 6.0.1  Chrome Mobile 65.0            1.0         189
# 4            Android 6.0.1  Chrome Mobile 65.0            1.0         189

# %%
# convertimos a integer el valor flotante de visitas_sitio
sets['visitas_sitio'] = sets['visitas_sitio'].astype('int')
sets.head()
# Out:
#                fecha_x    person                    model  condition storage  \
# 0  2018-05-18 00:11:56  4886f805  Samsung Galaxy J7 Prime  Excelente    32GB
# 1  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 2  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 3  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
# 4  2018-05-22 20:29:35  0297fc1e                iPhone 6S        Bom    32GB
#
#        color  compras_prod  vistas_prod  otros              fecha_y  \
# 0    Dourado             1            0      0  2018-05-18 00:07:22
# 1  Ouro Rosa             1            0      0  2018-05-02 01:28:27
# 2  Ouro Rosa             1            0      0  2018-05-02 14:28:20
# 3  Ouro Rosa             1            0      0  2018-05-03 01:55:52
# 4  Ouro Rosa             1            0      0  2018-05-10 00:38:17
#
#   new_vs_returning          region country device_type screen_resolution  \
# 0              New  Rio de Janeiro  Brazil  Smartphone           360x640
# 1        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 2        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 3        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
# 4        Returning  Rio de Janeiro  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  visitas_sitio  person_int
# 0                Android 7  Chrome Mobile 64.0              1        5476
# 1            Android 6.0.1  Chrome Mobile 65.0              1         189
# 2            Android 6.0.1  Chrome Mobile 65.0              1         189
# 3            Android 6.0.1  Chrome Mobile 65.0              1         189
# 4            Android 6.0.1  Chrome Mobile 65.0              1         189

# %%
#Categorizamos los valores de los features con label encoder
sets['model'] = labelencoder.fit_transform(sets['model'])
sets['condition'] = labelencoder.fit_transform(sets['condition'])
sets['storage'] = labelencoder.fit_transform(sets['storage'])
sets['color'] = labelencoder.fit_transform(sets['color'])
sets['new_vs_returning'] = labelencoder.fit_transform(sets['new_vs_returning'])
sets['region'] = labelencoder.fit_transform(sets['region'])
sets['country'] = labelencoder.fit_transform(sets['country'])
sets['device_type'] = labelencoder.fit_transform(sets['device_type'])
sets['screen_resolution'] = labelencoder.fit_transform(sets['screen_resolution'])
sets['operating_system_version'] = labelencoder.fit_transform(sets['operating_system_version'])
sets['browser_version'] = labelencoder.fit_transform(sets['browser_version'])
sets.head()
# Out:
#                fecha_x    person  model  condition  storage  color  \
# 0  2018-05-18 00:11:56  4886f805     97          3        4     28
# 1  2018-05-22 20:29:35  0297fc1e    180          1        4     34
# 2  2018-05-22 20:29:35  0297fc1e    180          1        4     34
# 3  2018-05-22 20:29:35  0297fc1e    180          1        4     34
# 4  2018-05-22 20:29:35  0297fc1e    180          1        4     34
#
#    compras_prod  vistas_prod  otros              fecha_y  new_vs_returning  \
# 0             1            0      0  2018-05-18 00:07:22                 1
# 1             1            0      0  2018-05-02 01:28:27                 2
# 2             1            0      0  2018-05-02 14:28:20                 2
# 3             1            0      0  2018-05-03 01:55:52                 2
# 4             1            0      0  2018-05-10 00:38:17                 2
#
#    region  country  device_type  screen_resolution  operating_system_version  \
# 0      78        7            2                170                        24
# 1      78        7            2                170                        22
# 2      78        7            2                170                        22
# 3      78        7            2                170                        22
# 4      78        7            2                170                        22
#
#    browser_version  visitas_sitio  person_int
# 0              110              1        5476
# 1              111              1         189
# 2              111              1         189
# 3              111              1         189
# 4              111              1         189

# %%
#Categorizamos la fecha del visto del producto en dia hora y minuto (ya que el anio es 2018)
sets['dia_view_prod'] = sets['fecha_x'].apply(lambda x: x.day if type(x) != str else 0).astype('int')
sets['mes_view_prod'] = sets['fecha_x'].apply(lambda x: x.month if type(x) != str else 0).astype('int')
sets['dia_sem_view_prod'] = sets['fecha_x'].apply(lambda x: x.dayofweek if type(x) != str else 0).astype('int')
sets = sets.drop('fecha_x',1)

# %%
#Categorizamos la fecha de visita del usuario en dia mes hora y minuto (ya que el anio es 2018)
sets['dia_visit_user'] = sets['fecha_y'].apply(lambda x: x.day if type(x) != str else 0).astype('int')
sets['mes_visit_user'] = sets['fecha_y'].apply(lambda x: x.month if type(x) != str else 0).astype('int')
sets['dia_sem_visit_user'] = sets['fecha_y'].apply(lambda x: x.dayofweek if type(x) != str else 0).astype('int')
sets = sets.drop('fecha_y',1)

# %%
sets.head()
# Out:
#      person  model  condition  storage  color  compras_prod  vistas_prod  \
# 0  4886f805     97          3        4     28             1            0
# 1  0297fc1e    180          1        4     34             1            0
# 2  0297fc1e    180          1        4     34             1            0
# 3  0297fc1e    180          1        4     34             1            0
# 4  0297fc1e    180          1        4     34             1            0
#
#    otros  new_vs_returning  region         ...          \
# 0      0                 1      78         ...
# 1      0                 2      78         ...
# 2      0                 2      78         ...
# 3      0                 2      78         ...
# 4      0                 2      78         ...
#
#    operating_system_version  browser_version  visitas_sitio  person_int  \
# 0                        24              110              1        5476
# 1                        22              111              1         189
# 2                        22              111              1         189
# 3                        22              111              1         189
# 4                        22              111              1         189
#
#    dia_view_prod  mes_view_prod  dia_sem_view_prod  dia_visit_user  \
# 0             18              5                  4              18
# 1             22              5                  1               2
# 2             22              5                  1               2
# 3             22              5                  1               3
# 4             22              5                  1              10
#
#    mes_visit_user  dia_sem_visit_user
# 0               5                   4
# 1               5                   2
# 2               5                   2
# 3               5                   3
# 4               5                   3
#
# [5 rows x 23 columns]

# %%
sets.tail()
# Out:
#         person  model  condition  storage  color  compras_prod  vistas_prod  \
# 3872  85e0f62a      0          0        0      0             0            0
# 3873  85e0f62a      0          0        0      0             0            0
# 3874  92f2d94b     67          0        0      0             0            0
# 3875  40bf23ab    180          0        0      0             0            0
# 3876  80aea0a0    151          0        0      0             0            0
#
#       otros  new_vs_returning  region         ...          \
# 3872      1                 1      79         ...
# 3873      1                 2      79         ...
# 3874      1                 0       0         ...
# 3875      1                 0       0         ...
# 3876      1                 0       0         ...
#
#       operating_system_version  browser_version  visitas_sitio  person_int  \
# 3872                        20              112              1       10087
# 3873                        20              112              1       10087
# 3874                         0                0              0       11118
# 3875                         0                0              0        4896
# 3876                         0                0              0        9700
#
#       dia_view_prod  mes_view_prod  dia_sem_view_prod  dia_visit_user  \
# 3872             31              5                  3              31
# 3873             31              5                  3              31
# 3874             23              3                  4               0
# 3875             30              5                  2               0
# 3876             30              5                  2               0
#
#       mes_visit_user  dia_sem_visit_user
# 3872               5                   3
# 3873               5                   3
# 3874               0                   0
# 3875               0                   0
# 3876               0                   0
#
# [5 rows x 23 columns]

# %%
sets.person.describe()
# Out:
# count      1293877
# unique       19415
# top       5059f7fd
# freq         96465
# Name: person, dtype: object

# %%
sets.to_csv('data/set_prediccion_14.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Set Datos Entrenamiento

# %% [markdown]
# # #Analisis TP1

# %%
training_set.columns
# Out:
# Index(['timestamp', 'event', 'person', 'url', 'sku', 'model', 'condition',
#        'storage', 'color', 'skus', 'search_term', 'staticpage',
#        'campaign_source', 'search_engine', 'channel', 'new_vs_returning',
#        'city', 'region', 'country', 'device_type', 'screen_resolution',
#        'operating_system_version', 'browser_version', 'label'],
#       dtype='object')

# %%
training_set.drop(['url','skus', 'sku', 'city','search_engine','campaign_source','channel'], inplace=True, axis=1)

# %%
#Cambiamos el tipo de dato de fecha de timestamp a datetime para un mejor analisis y renombramos a "fecha"
training_set[['timestamp']] = training_set[['timestamp']].apply(pd.to_datetime)
training_set.rename({
    'timestamp' : 'fecha',
}, axis=1, inplace=True)
training_set.head()
# Out:
#                 fecha            event    person      model  \
# 0 2018-05-18 00:11:27   viewed product  ad93850f  iPhone 5s
# 1 2018-05-18 00:23:33   viewed product  ad93850f  iPhone 5s
# 2 2018-05-18 00:16:10   viewed product  ad93850f  iPhone 5s
# 3 2018-05-18 00:14:55   viewed product  ad93850f  iPhone 5s
# 4 2018-05-18 00:11:26  ad campaign hit  ad93850f        NaN
#
#             condition storage           color search_term staticpage  \
# 0           Muito Bom    32GB  Cinza espacial         NaN        NaN
# 1           Muito Bom    64GB        Prateado         NaN        NaN
# 2  Bom - Sem Touch ID    16GB  Cinza espacial         NaN        NaN
# 3  Bom - Sem Touch ID    16GB         Dourado         NaN        NaN
# 4                 NaN     NaN             NaN         NaN        NaN
#
#   new_vs_returning region country device_type screen_resolution  \
# 0              NaN    NaN     NaN         NaN               NaN
# 1              NaN    NaN     NaN         NaN               NaN
# 2              NaN    NaN     NaN         NaN               NaN
# 3              NaN    NaN     NaN         NaN               NaN
# 4              NaN    NaN     NaN         NaN               NaN
#
#   operating_system_version browser_version  label
# 0                      NaN             NaN      0
# 1                      NaN             NaN      0
# 2                      NaN             NaN      0
# 3                      NaN             NaN      0
# 4                      NaN             NaN      0

# %% [markdown]
# vamos a crear las columnas compras_prod, vistas_prod, otros para productos y visitas_sitio para persona, de la forma de One Hot Encoder

# %%
#Detalles de Productos que fueron comprados
productos = training_set.loc[:, ['event','fecha','person', 'model', 'condition', 'storage', 'color', 'label']]
productos_comprados = productos[(productos['event'] == 'conversion') | (productos['event'] == 'checkout')]
productos_comprados.drop(['event'], inplace=True, axis=1)
productos_comprados['compras_prod'] = 1
productos_comprados['vistas_prod'] = 0
productos_comprados['otros'] = 0
productos_comprados.head()
# Out:
#                   fecha    person                    model  condition storage  \
# 36  2018-05-14 23:54:19  ad93850f                iPhone 5s  Muito Bom    32GB
# 72  2018-05-18 00:44:49  1b9f7cf6                 iPhone 6        Bom    64GB
# 125 2018-05-18 01:00:16  de8fe91b  Samsung Galaxy J7 Prime  Excelente    32GB
# 152 2018-05-18 00:48:20  45baf068   Samsung Galaxy S6 Flat        Bom    32GB
# 211 2018-05-09 00:13:59  99abca5a    Motorola Moto G4 Plus  Excelente    32GB
#
#               color  label  compras_prod  vistas_prod  otros
# 36   Cinza espacial      0             1            0      0
# 72          Dourado      0             1            0      0
# 125         Dourado      0             1            0      0
# 152         Dourado      0             1            0      0
# 211           Bambu      0             1            0      0

# %%
productos_comprados.count()
# Out:
# fecha           36103
# person          36103
# model           36103
# condition       36103
# storage         36103
# color           36103
# label           36103
# compras_prod    36103
# vistas_prod     36103
# otros           36103
# dtype: int64

# %%
# productos_comprados = productos_comprados.drop_duplicates()
# productos_comprados.count()

# %%
#Detalles de Productos que fueron visitados
productos_visitados = productos.loc[productos.event == 'viewed product']
productos_visitados.drop(['event'], inplace=True, axis=1)
productos_visitados['compras_prod'] = 0
productos_visitados['vistas_prod'] = 1
productos_visitados['otros'] = 0
productos_visitados.head()
# Out:
#                 fecha    person      model           condition storage  \
# 0 2018-05-18 00:11:27  ad93850f  iPhone 5s           Muito Bom    32GB
# 1 2018-05-18 00:23:33  ad93850f  iPhone 5s           Muito Bom    64GB
# 2 2018-05-18 00:16:10  ad93850f  iPhone 5s  Bom - Sem Touch ID    16GB
# 3 2018-05-18 00:14:55  ad93850f  iPhone 5s  Bom - Sem Touch ID    16GB
# 5 2018-05-16 02:48:16  ad93850f  iPhone 5s           Muito Bom    32GB
#
#             color  label  compras_prod  vistas_prod  otros
# 0  Cinza espacial      0             0            1      0
# 1        Prateado      0             0            1      0
# 2  Cinza espacial      0             0            1      0
# 3         Dourado      0             0            1      0
# 5  Cinza espacial      0             0            1      0

# %%
productos_visitados.count()
# Out:
# fecha           629233
# person          629233
# model           629233
# condition       629233
# storage         629233
# color           629233
# label           629233
# compras_prod    629233
# vistas_prod     629233
# otros           629233
# dtype: int64

# %%
# productos_visitados = productos_comprados.drop_duplicates()
# productos_visitados.count()

# %%
# Eliminamos de productos visitados las personas que estan en productos comprados
productos_visitados = productos_visitados.merge(productos_comprados, on='person', how='left')
productos_visitados = productos_visitados[productos_visitados['fecha_y'].isnull()]
productos_visitados = productos_visitados.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x', 'label_x']]
productos_visitados.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros', 'label_x': 'label'}, inplace=True)
productos_visitados.head()
# Out:
#                     fecha    person                   model condition storage  \
# 25576 2018-05-18 00:18:24  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 25577 2018-05-18 00:15:33  9bb3af27       Samsung Galaxy S5       Bom    16GB
# 25578 2018-05-18 00:20:10  9bb3af27       Samsung Galaxy S5       Bom    16GB
# 25579 2018-05-18 00:21:58  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 25580 2018-05-18 00:14:35  9bb3af27       Samsung Galaxy S5       Bom    16GB
#
#          color  compras_prod  vistas_prod  otros  label
# 25576  Dourado             0            1      0      1
# 25577    Preto             0            1      0      1
# 25578   Branco             0            1      0      1
# 25579  Dourado             0            1      0      1
# 25580  Dourado             0            1      0      1

# %%
productos_visitados.count()
# Out:
# fecha           52146
# person          52146
# model           52146
# condition       52146
# storage         52146
# color           52146
# compras_prod    52146
# vistas_prod     52146
# otros           52146
# label           52146
# dtype: int64

# %%
otros = training_set.loc[:, ['event','fecha','person', 'model', 'condition', 'storage', 'color','label']]
otros = otros[(otros['event'] == 'generic listing') | (otros['event'] == 'lead')]
otros.drop(['event'], inplace=True, axis=1)
otros['compras_prod'] = 0
otros['vistas_prod'] = 0
otros['otros'] = 1
otros.head()
# Out:
#                  fecha    person model condition storage color  label  \
# 38 2018-05-14 23:50:23  ad93850f   NaN       NaN     NaN   NaN      0
# 46 2018-05-18 00:12:55  ad93850f   NaN       NaN     NaN   NaN      0
# 53 2018-05-18 00:23:21  ad93850f   NaN       NaN     NaN   NaN      0
# 54 2018-05-18 22:12:18  ad93850f   NaN       NaN     NaN   NaN      0
# 57 2018-05-18 22:11:47  ad93850f   NaN       NaN     NaN   NaN      0
#
#     compras_prod  vistas_prod  otros
# 38             0            0      1
# 46             0            0      1
# 53             0            0      1
# 54             0            0      1
# 57             0            0      1

# %%
otros.count()
# Out:
# fecha           80884
# person          80884
# model             431
# condition           0
# storage             0
# color               0
# label           80884
# compras_prod    80884
# vistas_prod     80884
# otros           80884
# dtype: int64

# %%
# otros = otros.drop_duplicates()
# otros.count()

# %%
# Eliminamos de otros las personas que estan en productos comprados
otros = otros.merge(productos_comprados, on='person', how='left')
otros = otros[otros['fecha_y'].isnull()]
otros = otros.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x', 'label_x']]
otros.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros', 'label_x': 'label'}, inplace=True)
otros.head()
# Out:
#                    fecha    person model condition storage color  \
# 1923 2018-05-18 00:11:31  9bb3af27   NaN       NaN     NaN   NaN
# 1924 2018-05-18 00:20:28  9bb3af27   NaN       NaN     NaN   NaN
# 1925 2018-05-18 00:22:23  9bb3af27   NaN       NaN     NaN   NaN
# 1926 2018-05-18 19:28:08  9bb3af27   NaN       NaN     NaN   NaN
# 1927 2018-05-18 19:26:43  9bb3af27   NaN       NaN     NaN   NaN
#
#       compras_prod  vistas_prod  otros  label
# 1923             0            0      1      1
# 1924             0            0      1      1
# 1925             0            0      1      1
# 1926             0            0      1      1
# 1927             0            0      1      1

# %%
otros.count()
# Out:
# fecha           7488
# person          7488
# model             32
# condition          0
# storage            0
# color              0
# compras_prod    7488
# vistas_prod     7488
# otros           7488
# label           7488
# dtype: int64

# %%
# Eliminamos de otros las personas que estan en productos visitados
otros = otros.merge(productos_visitados, on='person', how='left')
otros = otros[otros['fecha_y'].isnull()]
otros = otros.loc[:,['fecha_x','person', 'model_x', 'condition_x', 'storage_x', 'color_x','compras_prod_x','vistas_prod_x', 'otros_x', 'label_x']]
otros.rename(columns={'fecha_x': 'fecha', 'model_x': 'model', 'condition_x': 'condition', 'storage_x': 'storage', 'color_x': 'color', 'compras_prod_x': 'compras_prod', 'vistas_prod_x': 'vistas_prod' ,'otros_x': 'otros', 'label_x': 'label'}, inplace=True)
otros.head()
# Out:
#                     fecha    person model condition storage color  \
# 32460 2018-05-29 19:45:16  f33e2cc5   NaN       NaN     NaN   NaN
# 32845 2018-05-19 10:31:43  fb3c6e61   NaN       NaN     NaN   NaN
# 56829 2018-05-29 21:21:02  4042a213   NaN       NaN     NaN   NaN
# 56830 2018-05-18 14:20:44  9a84d509   NaN       NaN     NaN   NaN
# 56831 2018-05-18 14:24:27  9a84d509   NaN       NaN     NaN   NaN
#
#        compras_prod  vistas_prod  otros  label
# 32460             0            0      1      0
# 32845             0            0      1      0
# 56829             0            0      1      0
# 56830             0            0      1      0
# 56831             0            0      1      0

# %%
otros.count()
# Out:
# fecha           350
# person          350
# model             2
# condition         0
# storage           0
# color             0
# compras_prod    350
# vistas_prod     350
# otros           350
# label           350
# dtype: int64

# %%
#Caracterisitcas del dispositivos con el que el usuario visito el sitio
visitas = training_set.loc[:,['event','fecha','person','new_vs_returning','region','country','device_type','screen_resolution','operating_system_version','browser_version', 'label']]
features_usuario = visitas.loc[visitas.event == 'visited site']
features_usuario.drop(['event'], inplace=True, axis=1)
features_usuario['visitas_sitio'] = 1
features_usuario.head()
# Out:
#                  fecha    person new_vs_returning     region country  \
# 60 2018-05-14 23:50:22  ad93850f              New  Sao Paulo  Brazil
# 61 2018-05-16 02:48:13  ad93850f        Returning  Sao Paulo  Brazil
# 62 2018-05-18 00:11:26  ad93850f        Returning  Sao Paulo  Brazil
# 63 2018-05-18 22:11:46  ad93850f        Returning  Sao Paulo  Brazil
# 64 2018-05-22 22:41:31  ad93850f        Returning  Sao Paulo  Brazil
#
#    device_type screen_resolution operating_system_version     browser_version  \
# 60  Smartphone           360x640            Android 5.1.1  Chrome Mobile 66.0
# 61  Smartphone           360x640            Android 5.1.1  Chrome Mobile 66.0
# 62  Smartphone           360x640            Android 5.1.1  Chrome Mobile 66.0
# 63  Smartphone           360x640            Android 5.1.1  Chrome Mobile 66.0
# 64  Smartphone           360x640            Android 5.1.1  Chrome Mobile 66.0
#
#     label  visitas_sitio
# 60      0              1
# 61      0              1
# 62      0              1
# 63      0              1
# 64      0              1

# %%
features_usuario.count()
# Out:
# fecha                       102299
# person                      102299
# new_vs_returning            102299
# region                      102299
# country                     102299
# device_type                 102299
# screen_resolution           102297
# operating_system_version    102299
# browser_version             102299
# label                       102299
# visitas_sitio               102299
# dtype: int64

# %%
features_usuario = features_usuario.drop_duplicates()
features_usuario.count()
# Out:
# fecha                       102298
# person                      102298
# new_vs_returning            102298
# region                      102298
# country                     102298
# device_type                 102298
# screen_resolution           102296
# operating_system_version    102298
# browser_version             102298
# label                       102298
# visitas_sitio               102298
# dtype: int64

# %%
del productos
del visitas

# %%
user_prod_comprados = productos_comprados.merge(features_usuario, on="person", how="outer")
user_prod_comprados.head()
# Out:
#               fecha_x    person      model  condition storage           color  \
# 0 2018-05-14 23:54:19  ad93850f  iPhone 5s  Muito Bom    32GB  Cinza espacial
# 1 2018-05-14 23:54:19  ad93850f  iPhone 5s  Muito Bom    32GB  Cinza espacial
# 2 2018-05-14 23:54:19  ad93850f  iPhone 5s  Muito Bom    32GB  Cinza espacial
# 3 2018-05-14 23:54:19  ad93850f  iPhone 5s  Muito Bom    32GB  Cinza espacial
# 4 2018-05-14 23:54:19  ad93850f  iPhone 5s  Muito Bom    32GB  Cinza espacial
#
#    label_x  compras_prod  vistas_prod  otros             fecha_y  \
# 0      0.0           1.0          0.0    0.0 2018-05-14 23:50:22
# 1      0.0           1.0          0.0    0.0 2018-05-16 02:48:13
# 2      0.0           1.0          0.0    0.0 2018-05-18 00:11:26
# 3      0.0           1.0          0.0    0.0 2018-05-18 22:11:46
# 4      0.0           1.0          0.0    0.0 2018-05-22 22:41:31
#
#   new_vs_returning     region country device_type screen_resolution  \
# 0              New  Sao Paulo  Brazil  Smartphone           360x640
# 1        Returning  Sao Paulo  Brazil  Smartphone           360x640
# 2        Returning  Sao Paulo  Brazil  Smartphone           360x640
# 3        Returning  Sao Paulo  Brazil  Smartphone           360x640
# 4        Returning  Sao Paulo  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  label_y  visitas_sitio
# 0            Android 5.1.1  Chrome Mobile 66.0      0.0            1.0
# 1            Android 5.1.1  Chrome Mobile 66.0      0.0            1.0
# 2            Android 5.1.1  Chrome Mobile 66.0      0.0            1.0
# 3            Android 5.1.1  Chrome Mobile 66.0      0.0            1.0
# 4            Android 5.1.1  Chrome Mobile 66.0      0.0            1.0

# %%
user_prod_comprados.count()
# Out:
# fecha_x                     487502
# person                      497917
# model                       487502
# condition                   487502
# storage                     487502
# color                       487502
# label_x                     487502
# compras_prod                487502
# vistas_prod                 487502
# otros                       487502
# fecha_y                     497450
# new_vs_returning            497450
# region                      497450
# country                     497450
# device_type                 497450
# screen_resolution           497437
# operating_system_version    497450
# browser_version             497450
# label_y                     497450
# visitas_sitio               497450
# dtype: int64

# %%
user_prod_vistas = productos_visitados.merge(features_usuario, on="person", how="outer")
user_prod_vistas.head()
# Out:
#               fecha_x    person                   model condition storage  \
# 0 2018-05-18 00:18:24  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 1 2018-05-18 00:18:24  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 2 2018-05-18 00:18:24  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 3 2018-05-18 00:18:24  9bb3af27  Samsung Galaxy S6 Flat       Bom    32GB
# 4 2018-05-18 00:15:33  9bb3af27       Samsung Galaxy S5       Bom    16GB
#
#      color  compras_prod  vistas_prod  otros  label_x             fecha_y  \
# 0  Dourado           0.0          1.0    0.0      1.0 2018-05-17 17:16:36
# 1  Dourado           0.0          1.0    0.0      1.0 2018-05-17 21:45:43
# 2  Dourado           0.0          1.0    0.0      1.0 2018-05-18 00:11:31
# 3  Dourado           0.0          1.0    0.0      1.0 2018-05-18 19:26:42
# 4    Preto           0.0          1.0    0.0      1.0 2018-05-17 17:16:36
#
#   new_vs_returning        region country device_type screen_resolution  \
# 0              New  Minas Gerais  Brazil  Smartphone           320x534
# 1        Returning  Minas Gerais  Brazil  Smartphone           320x534
# 2        Returning  Minas Gerais  Brazil  Smartphone           320x534
# 3        Returning  Minas Gerais  Brazil  Smartphone           320x534
# 4              New  Minas Gerais  Brazil  Smartphone           320x534
#
#   operating_system_version     browser_version  label_y  visitas_sitio
# 0                Android 6  Chrome Mobile 66.0      1.0            1.0
# 1                Android 6  Chrome Mobile 66.0      1.0            1.0
# 2                Android 6  Chrome Mobile 66.0      1.0            1.0
# 3                Android 6  Chrome Mobile 66.0      1.0            1.0
# 4                Android 6  Chrome Mobile 66.0      1.0            1.0

# %%
user_prod_vistas.count()
# Out:
# fecha_x                     582196
# person                      674544
# model                       582196
# condition                   582196
# storage                     582196
# color                       582196
# compras_prod                582196
# vistas_prod                 582196
# otros                       582196
# label_x                     582196
# fecha_y                     674421
# new_vs_returning            674421
# region                      674421
# country                     674421
# device_type                 674421
# screen_resolution           674419
# operating_system_version    674421
# browser_version             674421
# label_y                     674421
# visitas_sitio               674421
# dtype: int64

# %%
otros = otros.merge(features_usuario, on="person", how="outer")
otros.head()
# Out:
#               fecha_x    person model condition storage color  compras_prod  \
# 0 2018-05-29 19:45:16  f33e2cc5   NaN       NaN     NaN   NaN           0.0
# 1 2018-05-19 10:31:43  fb3c6e61   NaN       NaN     NaN   NaN           0.0
# 2 2018-05-29 21:21:02  4042a213   NaN       NaN     NaN   NaN           0.0
# 3 2018-05-18 14:20:44  9a84d509   NaN       NaN     NaN   NaN           0.0
# 4 2018-05-18 14:20:44  9a84d509   NaN       NaN     NaN   NaN           0.0
#
#    vistas_prod  otros  label_x             fecha_y new_vs_returning  \
# 0          0.0    1.0      0.0 2018-05-29 19:45:16              New
# 1          0.0    1.0      0.0 2018-05-19 10:31:42              New
# 2          0.0    1.0      0.0 2018-05-29 21:21:02              New
# 3          0.0    1.0      0.0 2018-05-29 22:59:02        Returning
# 4          0.0    1.0      0.0 2018-05-18 14:20:10              New
#
#            region country device_type screen_resolution  \
# 0       Sao Paulo  Brazil  Smartphone           360x640
# 1      Pernambuco  Brazil  Smartphone           360x640
# 2  Rio de Janeiro  Brazil  Smartphone           320x570
# 3           Ceara  Brazil  Smartphone           360x640
# 4           Ceara  Brazil  Smartphone           360x640
#
#   operating_system_version     browser_version  label_y  visitas_sitio
# 0                Android 7  Chrome Mobile 66.0      0.0            1.0
# 1                Android 6  Chrome Mobile 66.0      0.0            1.0
# 2                Android 6  Chrome Mobile 64.0      0.0            1.0
# 3                Android 7  Chrome Mobile 66.0      0.0            1.0
# 4                Android 7  Chrome Mobile 66.0      0.0            1.0

# %%
otros.count()
# Out:
# fecha_x                       1505
# person                      103462
# model                            2
# condition                        0
# storage                          0
# color                            0
# compras_prod                  1505
# vistas_prod                   1505
# otros                         1505
# label_x                       1505
# fecha_y                     103454
# new_vs_returning            103454
# region                      103454
# country                     103454
# device_type                 103454
# screen_resolution           103452
# operating_system_version    103454
# browser_version             103454
# label_y                     103454
# visitas_sitio               103454
# dtype: int64

# %%
del features_usuario
del productos_comprados
del productos_visitados

# %%
#concateno
frames = [user_prod_comprados, user_prod_vistas, otros]
sets = pd.concat(frames)
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
#
#   device_type             fecha_x             fecha_y  label_x  label_y  \
# 0  Smartphone 2018-05-14 23:54:19 2018-05-14 23:50:22      0.0      0.0
# 1  Smartphone 2018-05-14 23:54:19 2018-05-16 02:48:13      0.0      0.0
# 2  Smartphone 2018-05-14 23:54:19 2018-05-18 00:11:26      0.0      0.0
# 3  Smartphone 2018-05-14 23:54:19 2018-05-18 22:11:46      0.0      0.0
# 4  Smartphone 2018-05-14 23:54:19 2018-05-22 22:41:31      0.0      0.0
#
#        model new_vs_returning operating_system_version  otros    person  \
# 0  iPhone 5s              New            Android 5.1.1    0.0  ad93850f
# 1  iPhone 5s        Returning            Android 5.1.1    0.0  ad93850f
# 2  iPhone 5s        Returning            Android 5.1.1    0.0  ad93850f
# 3  iPhone 5s        Returning            Android 5.1.1    0.0  ad93850f
# 4  iPhone 5s        Returning            Android 5.1.1    0.0  ad93850f
#
#       region screen_resolution storage  visitas_sitio  vistas_prod
# 0  Sao Paulo           360x640    32GB            1.0          0.0
# 1  Sao Paulo           360x640    32GB            1.0          0.0
# 2  Sao Paulo           360x640    32GB            1.0          0.0
# 3  Sao Paulo           360x640    32GB            1.0          0.0
# 4  Sao Paulo           360x640    32GB            1.0          0.0

# %%
del frames
del user_prod_comprados
del user_prod_vistas
del otros

# %%
sets.count()
# Out:
# browser_version             1275325
# color                       1069698
# compras_prod                1071203
# condition                   1069698
# country                     1275325
# device_type                 1275325
# fecha_x                     1071203
# fecha_y                     1275325
# label_x                     1071203
# label_y                     1275325
# model                       1069700
# new_vs_returning            1275325
# operating_system_version    1275325
# otros                       1071203
# person                      1275923
# region                      1275325
# screen_resolution           1275308
# storage                     1069698
# visitas_sitio               1275325
# vistas_prod                 1071203
# dtype: int64

# %%
sets = sets.drop_duplicates()

# %%
sets.count()
# Out:
# browser_version             1171058
# color                       1067853
# compras_prod                1069358
# condition                   1067853
# country                     1171058
# device_type                 1171058
# fecha_x                     1069358
# fecha_y                     1171058
# label_x                     1069358
# label_y                     1171058
# model                       1067855
# new_vs_returning            1171058
# operating_system_version    1171058
# otros                       1069358
# person                      1171656
# region                      1171058
# screen_resolution           1171043
# storage                     1067853
# visitas_sitio               1171058
# vistas_prod                 1069358
# dtype: int64

# %%
# Rellenamos compras_prod  vistas_prod  otros y visitas_sitio con 0
sets['compras_prod'] = sets['compras_prod'].fillna(value=0) 
sets['vistas_prod'] = sets['vistas_prod'].fillna(value=0) 
sets['otros'] = sets['otros'].fillna(value=0) 
sets['visitas_sitio'] = sets['visitas_sitio'].fillna(value=0)

# %%
sets.count()
# Out:
# browser_version             1171058
# color                       1067853
# compras_prod                1171656
# condition                   1067853
# country                     1171058
# device_type                 1171058
# fecha_x                     1069358
# fecha_y                     1171058
# label_x                     1069358
# label_y                     1171058
# model                       1067855
# new_vs_returning            1171058
# operating_system_version    1171058
# otros                       1171656
# person                      1171656
# region                      1171058
# screen_resolution           1171043
# storage                     1067853
# visitas_sitio               1171656
# vistas_prod                 1171656
# dtype: int64

# %%
# Rellenamos label_x y label_y con 0 y nos quedamos con label
sets['label_x'] = sets['label_x'].fillna(value=0) 
sets['label_y'] = sets['label_y'].fillna(value=0) 
sets.loc[(sets['label_x'] == 1) | (sets['label_y'] == 1), 'label'] = 1
sets['label'] = sets['label'].fillna(value=0) 
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
#
#   device_type             fecha_x             fecha_y  label_x  label_y  \
# 0  Smartphone 2018-05-14 23:54:19 2018-05-14 23:50:22      0.0      0.0
# 1  Smartphone 2018-05-14 23:54:19 2018-05-16 02:48:13      0.0      0.0
# 2  Smartphone 2018-05-14 23:54:19 2018-05-18 00:11:26      0.0      0.0
# 3  Smartphone 2018-05-14 23:54:19 2018-05-18 22:11:46      0.0      0.0
# 4  Smartphone 2018-05-14 23:54:19 2018-05-22 22:41:31      0.0      0.0
#
#    ...   new_vs_returning operating_system_version otros    person     region  \
# 0  ...                New            Android 5.1.1   0.0  ad93850f  Sao Paulo
# 1  ...          Returning            Android 5.1.1   0.0  ad93850f  Sao Paulo
# 2  ...          Returning            Android 5.1.1   0.0  ad93850f  Sao Paulo
# 3  ...          Returning            Android 5.1.1   0.0  ad93850f  Sao Paulo
# 4  ...          Returning            Android 5.1.1   0.0  ad93850f  Sao Paulo
#
#   screen_resolution storage visitas_sitio  vistas_prod  label
# 0           360x640    32GB           1.0          0.0    0.0
# 1           360x640    32GB           1.0          0.0    0.0
# 2           360x640    32GB           1.0          0.0    0.0
# 3           360x640    32GB           1.0          0.0    0.0
# 4           360x640    32GB           1.0          0.0    0.0
#
# [5 rows x 21 columns]

# %%
sets[sets['label'] == 1].shape
# Out:
# (276643, 21)

# %%
sets[sets['label'] == 0].shape
# Out:
# (895013, 21)

# %%
sets = sets.drop('label_x',1)
sets = sets.drop('label_y',1)
sets.count()
# Out:
# browser_version             1171058
# color                       1067853
# compras_prod                1171656
# condition                   1067853
# country                     1171058
# device_type                 1171058
# fecha_x                     1069358
# fecha_y                     1171058
# model                       1067855
# new_vs_returning            1171058
# operating_system_version    1171058
# otros                       1171656
# person                      1171656
# region                      1171058
# screen_resolution           1171043
# storage                     1067853
# visitas_sitio               1171656
# vistas_prod                 1171656
# label                       1171656
# dtype: int64

# %%
# Rellenamos los demas con ''
sets = sets.fillna(value='')

# %%
sets.count()
# Out:
# browser_version             1171656
# color                       1171656
# compras_prod                1171656
# condition                   1171656
# country                     1171656
# device_type                 1171656
# fecha_x                     1171656
# fecha_y                     1171656
# model                       1171656
# new_vs_returning            1171656
# operating_system_version    1171656
# otros                       1171656
# person                      1171656
# region                      1171656
# screen_resolution           1171656
# storage                     1171656
# visitas_sitio               1171656
# vistas_prod                 1171656
# label                       1171656
# dtype: int64

# %%
sets.person.describe()
# Out:
# count      1171656
# unique       19414
# top       ecd79d0a
# freq         33950
# Name: person, dtype: object

# %% [markdown]
# ## Categorizacion de los features

# %%
# creo una nueva columna person_int para entrenar transformando el valor alfanumerico de person a numerico
sets['person_int'] = labelencoder.fit_transform(sets['person'])
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial           1.0  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB            1.0          0.0    0.0       13068
# 1           360x640    32GB            1.0          0.0    0.0       13068
# 2           360x640    32GB            1.0          0.0    0.0       13068
# 3           360x640    32GB            1.0          0.0    0.0       13068
# 4           360x640    32GB            1.0          0.0    0.0       13068

# %%
# convertimos a integer el valor flotante de compras_prod
sets['compras_prod'] = sets['compras_prod'].astype('int')
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB            1.0          0.0    0.0       13068
# 1           360x640    32GB            1.0          0.0    0.0       13068
# 2           360x640    32GB            1.0          0.0    0.0       13068
# 3           360x640    32GB            1.0          0.0    0.0       13068
# 4           360x640    32GB            1.0          0.0    0.0       13068

# %%
# convertimos a integer el valor flotante de vistas_prod
sets['vistas_prod'] = sets['vistas_prod'].astype('int')
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1    0.0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB            1.0            0    0.0       13068
# 1           360x640    32GB            1.0            0    0.0       13068
# 2           360x640    32GB            1.0            0    0.0       13068
# 3           360x640    32GB            1.0            0    0.0       13068
# 4           360x640    32GB            1.0            0    0.0       13068

# %%
# convertimos a integer el valor flotante de otros
sets['otros'] = sets['otros'].astype('int')
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1      0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB            1.0            0    0.0       13068
# 1           360x640    32GB            1.0            0    0.0       13068
# 2           360x640    32GB            1.0            0    0.0       13068
# 3           360x640    32GB            1.0            0    0.0       13068
# 4           360x640    32GB            1.0            0    0.0       13068

# %%
# convertimos a integer el valor flotante de visitas_sitio
sets['visitas_sitio'] = sets['visitas_sitio'].astype('int')
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1      0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB              1            0    0.0       13068
# 1           360x640    32GB              1            0    0.0       13068
# 2           360x640    32GB              1            0    0.0       13068
# 3           360x640    32GB              1            0    0.0       13068
# 4           360x640    32GB              1            0    0.0       13068

# %%
# convertimos a integer el valor flotante de label
sets['label'] = sets['label'].astype('int')
sets.head()
# Out:
#       browser_version           color  compras_prod  condition country  \
# 0  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 1  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 2  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 3  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
# 4  Chrome Mobile 66.0  Cinza espacial             1  Muito Bom  Brazil
#
#   device_type              fecha_x              fecha_y      model  \
# 0  Smartphone  2018-05-14 23:54:19  2018-05-14 23:50:22  iPhone 5s
# 1  Smartphone  2018-05-14 23:54:19  2018-05-16 02:48:13  iPhone 5s
# 2  Smartphone  2018-05-14 23:54:19  2018-05-18 00:11:26  iPhone 5s
# 3  Smartphone  2018-05-14 23:54:19  2018-05-18 22:11:46  iPhone 5s
# 4  Smartphone  2018-05-14 23:54:19  2018-05-22 22:41:31  iPhone 5s
#
#   new_vs_returning operating_system_version  otros    person     region  \
# 0              New            Android 5.1.1      0  ad93850f  Sao Paulo
# 1        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 2        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 3        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
# 4        Returning            Android 5.1.1      0  ad93850f  Sao Paulo
#
#   screen_resolution storage  visitas_sitio  vistas_prod  label  person_int
# 0           360x640    32GB              1            0      0       13068
# 1           360x640    32GB              1            0      0       13068
# 2           360x640    32GB              1            0      0       13068
# 3           360x640    32GB              1            0      0       13068
# 4           360x640    32GB              1            0      0       13068

# %%
#Categorizamos los valores de los features con label encoder
sets['model'] = labelencoder.fit_transform(sets['model'])
sets['condition'] = labelencoder.fit_transform(sets['condition'])
sets['storage'] = labelencoder.fit_transform(sets['storage'])
sets['color'] = labelencoder.fit_transform(sets['color'])
sets['new_vs_returning'] = labelencoder.fit_transform(sets['new_vs_returning'])
sets['region'] = labelencoder.fit_transform(sets['region'])
sets['country'] = labelencoder.fit_transform(sets['country'])
sets['device_type'] = labelencoder.fit_transform(sets['device_type'])
sets['screen_resolution'] = labelencoder.fit_transform(sets['screen_resolution'])
sets['operating_system_version'] = labelencoder.fit_transform(sets['operating_system_version'])
sets['browser_version'] = labelencoder.fit_transform(sets['browser_version'])
sets.head()
# Out:
#    browser_version  color  compras_prod  condition  country  device_type  \
# 0              103     21             1          4        5            2
# 1              103     21             1          4        5            2
# 2              103     21             1          4        5            2
# 3              103     21             1          4        5            2
# 4              103     21             1          4        5            2
#
#                fecha_x              fecha_y  model  new_vs_returning  \
# 0  2018-05-14 23:54:19  2018-05-14 23:50:22    176                 1
# 1  2018-05-14 23:54:19  2018-05-16 02:48:13    176                 2
# 2  2018-05-14 23:54:19  2018-05-18 00:11:26    176                 2
# 3  2018-05-14 23:54:19  2018-05-18 22:11:46    176                 2
# 4  2018-05-14 23:54:19  2018-05-22 22:41:31    176                 2
#
#    operating_system_version  otros    person  region  screen_resolution  \
# 0                        19      0  ad93850f      64                173
# 1                        19      0  ad93850f      64                173
# 2                        19      0  ad93850f      64                173
# 3                        19      0  ad93850f      64                173
# 4                        19      0  ad93850f      64                173
#
#    storage  visitas_sitio  vistas_prod  label  person_int
# 0        4              1            0      0       13068
# 1        4              1            0      0       13068
# 2        4              1            0      0       13068
# 3        4              1            0      0       13068
# 4        4              1            0      0       13068

# %%
#Categorizamos la fecha del visto del producto en dia hora y minuto (ya que el anio es 2018)
sets['dia_view_prod'] = sets['fecha_x'].apply(lambda x: x.day if type(x) != str else 0).astype('int')
sets['mes_view_prod'] = sets['fecha_x'].apply(lambda x: x.month if type(x) != str else 0).astype('int')
sets['dia_sem_view_prod'] = sets['fecha_x'].apply(lambda x: x.dayofweek if type(x) != str else 0).astype('int')
sets = sets.drop('fecha_x',1)

# %%
#Categorizamos la fecha de visita del usuario en dia mes hora y minuto (ya que el anio es 2018)
sets['dia_visit_user'] = sets['fecha_y'].apply(lambda x: x.day if type(x) != str else 0).astype('int')
sets['mes_visit_user'] = sets['fecha_y'].apply(lambda x: x.month if type(x) != str else 0).astype('int')
sets['dia_sem_visit_user'] = sets['fecha_y'].apply(lambda x: x.dayofweek if type(x) != str else 0).astype('int')
sets = sets.drop('fecha_y',1)

# %%
sets.head()
# Out:
#    browser_version  color  compras_prod  condition  country  device_type  \
# 0              103     21             1          4        5            2
# 1              103     21             1          4        5            2
# 2              103     21             1          4        5            2
# 3              103     21             1          4        5            2
# 4              103     21             1          4        5            2
#
#    model  new_vs_returning  operating_system_version  otros  \
# 0    176                 1                        19      0
# 1    176                 2                        19      0
# 2    176                 2                        19      0
# 3    176                 2                        19      0
# 4    176                 2                        19      0
#
#           ...         visitas_sitio  vistas_prod  label  person_int  \
# 0         ...                     1            0      0       13068
# 1         ...                     1            0      0       13068
# 2         ...                     1            0      0       13068
# 3         ...                     1            0      0       13068
# 4         ...                     1            0      0       13068
#
#    dia_view_prod  mes_view_prod  dia_sem_view_prod  dia_visit_user  \
# 0             14              5                  0              14
# 1             14              5                  0              16
# 2             14              5                  0              18
# 3             14              5                  0              18
# 4             14              5                  0              22
#
#    mes_visit_user  dia_sem_visit_user
# 0               5                   0
# 1               5                   2
# 2               5                   4
# 3               5                   4
# 4               5                   1
#
# [5 rows x 24 columns]

# %%
sets.tail()
# Out:
#       browser_version  color  compras_prod  condition  country  device_type  \
# 1500              225      0             0          0        5            2
# 1501              103      0             0          0        5            2
# 1502                0      0             0          0        0            0
# 1503                0      0             0          0        0            0
# 1504                0      0             0          0        0            0
#
#       model  new_vs_returning  operating_system_version  otros  \
# 1500      0                 2                        88      1
# 1501      0                 1                        19      1
# 1502      0                 0                         0      1
# 1503      0                 0                         0      1
# 1504      3                 0                         0      1
#
#              ...         visitas_sitio  vistas_prod  label  person_int  \
# 1500         ...                     1            0      0       15181
# 1501         ...                     1            0      0        1225
# 1502         ...                     0            0      0       10848
# 1503         ...                     0            0      0       10848
# 1504         ...                     0            0      0       16372
#
#       dia_view_prod  mes_view_prod  dia_sem_view_prod  dia_visit_user  \
# 1500             27              5                  6              27
# 1501             27              5                  6              28
# 1502             24              5                  3               0
# 1503             24              5                  3               0
# 1504             24              5                  3               0
#
#       mes_visit_user  dia_sem_visit_user
# 1500               5                   6
# 1501               5                   0
# 1502               0                   0
# 1503               0                   0
# 1504               0                   0
#
# [5 rows x 24 columns]

# %%
sets.count()
# Out:
# browser_version             1171656
# color                       1171656
# compras_prod                1171656
# condition                   1171656
# country                     1171656
# device_type                 1171656
# model                       1171656
# new_vs_returning            1171656
# operating_system_version    1171656
# otros                       1171656
# person                      1171656
# region                      1171656
# screen_resolution           1171656
# storage                     1171656
# visitas_sitio               1171656
# vistas_prod                 1171656
# label                       1171656
# person_int                  1171656
# dia_view_prod               1171656
# mes_view_prod               1171656
# dia_sem_view_prod           1171656
# dia_visit_user              1171656
# mes_visit_user              1171656
# dia_sem_visit_user          1171656
# dtype: int64

# %%
sets.person.describe()
# Out:
# count      1171656
# unique       19414
# top       ecd79d0a
# freq         33950
# Name: person, dtype: object

# %%
sets[sets['label'] == 1].shape
# Out:
# (276643, 24)

# %%
sets[sets['label'] == 0].shape
# Out:
# (895013, 24)

# %%
sets.to_csv('data/set_entrenamiento_14.csv', encoding='utf-8', index=False)
